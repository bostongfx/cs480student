# %% [markdown]
# <a href="https://colab.research.google.com/github/Robertkevin96/cs480student/blob/main/Copy_of_CS480_Assignment_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![CS480_w.png](data:image/png;base64,...)
# #Assignment 6

# %%
# In this assignment, we will train a U-Net classifer to detect mitochondria
# in electron microscopy images!

# %%
### IMPORTANT ###
#
# Activate GPU support: Runtime -> Change Runtime Type
# Hardware Accelerator: GPU
#
### IMPORTANT ###

# %%
# load numpy and matplotlib
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# load the unet tensorflow code
# !pip install git+https://github.com/jakeret/unet.git
# Out:
# Collecting git+https://github.com/jakeret/unet.git
#   Cloning https://github.com/jakeret/unet.git to /tmp/pip-req-build-20j55cl5
#   Running command git clone -q https://github.com/jakeret/unet.git /tmp/pip-req-build-20j55cl5
# Building wheels for collected packages: unet
#   Building wheel for unet (setup.py) ... done
#   Created wheel for unet: filename=unet-0.0.post0.dev81+gf557a51-py2.py3-none-any.whl size=25688 sha256=258c16c188e1d965991cab226b156b14354b3740c2cd3630ba56d1025928d6d8
#   Stored in directory: /tmp/pip-ephem-wheel-cache-em1qor3t/wheels/22/00/93/ce57529ed355f160088cbb6ce086e55168770913b40cf624ba
# Successfully built unet
# Installing collected packages: unet
# Successfully installed unet-0.0.post0.dev81+gf557a51

# %%
# .. and use it!
# Note: There are a ton of U-Net implementations but this one is easier to use!
import unet

# %% [markdown]
# **Task 1**: Study the unet circle example and learn about mitochondria! [15 Points]

# %%
# The unet package allows to train a U-Net classifier with little code.
# As discussed in class, the U-Net can be used to label/segment/annotate images.

# %%
# TODO: Please study the Circles example 
# https://github.com/jakeret/unet/blob/master/notebooks/circles.ipynb

# %%
# TODO: ... and look how the (artificial) dataset is generated
# https://github.com/jakeret/unet/blob/master/src/unet/datasets/circles.py

# %%
# 1) Question
# TODO: Please describe what the U-Net is trained to do.
#
# TODO: YOUR ANSWER

# %% [markdown]
# Unet is trained to fast and precisely segment the image.

# %%
# 2) Question
# TODO: In circles.py, what does the following mean:
#     channels = 1
#     classes = 2
#
# TODO: YOUR ANSWER

# %% [markdown]
# in a circle.py file the channels are the third parameters of a image dimension that represents the number of input images and classes will be number of categories in which the data will be segmented.

# %%
# 3) Question
# TODO: What are mitochondria and what is their appearance in
# electron microscopy data?
# Hint: You can validate your answer in Task 4!
#
# TODO: YOUR ANSWER

# %% [markdown]
# Mitochondria produces the power for a cell and shape of a mitochondria varies from circle to sausage shape under a electron microscope

# %% [markdown]
# **Task 2**: Setup a datagenerator for mitochondria images! [45 Points]

# %%
# TODO: 
# Download https://cs480.org/data/mito.npz to your computer.
# Then, please upload mito.npz using the file panel on the left.

# %%
# The code below is similar to the circles.py file from Task 1.
# We follow Tensorflow conventions to design a tf.data.Dataset for training
# the U-Net.
#
# TODO: Please add four different data augmentation methods in the code block
# below. (image normalization to 0..1, horizontal data flip, vertical data flip,
# rotation by 90 degrees)
#
# Hint: https://github.com/jakeret/unet/blob/master/src/unet/datasets/oxford_iiit_pet.py#L25

# %%
import tensorflow as tf
import tensorflow_datasets as tfds
from tensorflow_datasets.core import DatasetInfo
from typing import Tuple, List
import numpy as np


IMAGE_SIZE = (256, 256)
channels = 1
classes = 2

def load_data(count:int, splits:Tuple[float]=(0.7, 0.2, 0.1), **kwargs) -> List[tf.data.Dataset]:
    return [tf.data.Dataset.from_tensor_slices(_build_samples(int(split * count), **kwargs))
            for split in splits]


def _build_samples(sample_count:int, **kwargs) -> Tuple[np.array, np.array]:

    # here we load the mitochondria data
    loaded = np.load('mito.npz')
    loadedimages = loaded['arr_0'][0].copy()
    loadedmasks = loaded['arr_0'][1].copy()

    # now let's go to numpyland
    images = np.empty((sample_count, IMAGE_SIZE[0], IMAGE_SIZE[1], 1))
    labels = np.empty((sample_count, IMAGE_SIZE[0], IMAGE_SIZE[1], 2))
    for i in range(sample_count):
        image, mask = loadedimages[i], loadedmasks[i]

        image = image.reshape((IMAGE_SIZE[0], IMAGE_SIZE[1], 1)).astype(np.float)
        mask = mask.reshape((IMAGE_SIZE[0], IMAGE_SIZE[1], 1))

        #
        # TODO: Normalize the image to 0..1
        #
        # TODO: YOUR CODE
        image = tf.cast(image, tf.float32) / 255.0
        mask -= 1

        #
        # TODO: Use Tensorflow to flip the image horizontally
        #
        if tf.random.uniform(()) > 0.5:
            #
            # TODO: YOUR CODE
            image = tf.image.flip_left_right(image)
            mask = tf.image.flip_left_right(mask)

        #
        # TODO: Use Tensorflow to flip the image vertically
        #
        if tf.random.uniform(()) > 0.5:
            #
            # TODO: YOUR CODE
            image = tf.image.flip_up_down(image)
            mask = tf.image.flip_up_down(mask)


        #
        # TODO: Use Tensorflow to rotate the image 90 degrees
        #
        if tf.random.uniform(()) > 0.5:
            #
            # TODO: YOUR CODE
            image = tf.image.rot90(image)
            mask = tf.image.rot90(mask)



        # augmentation done, let's store the image
        images[i] = image

        # here we split the mask to background and foreground
        fg = np.zeros((IMAGE_SIZE[0], IMAGE_SIZE[1], 1), dtype=np.bool)
        fg[mask == 255] = 1
        bg = np.zeros((IMAGE_SIZE[0], IMAGE_SIZE[1], 1), dtype=np.bool)
        bg[mask == 0] = 1
        
        labels[i, :, :, 0] = bg[:,:,0]
        labels[i, :, :, 1] = fg[:,:,0]

    return images, labels

# %% [markdown]
# **Task 3**: Let's train the U-Net! [25 Points]

# %%
#
# We can now create our training, validation, and testing data by calling
# our methods from Task 2.
#
train, val, test = load_data( 660, splits=(0.7, 0.2, 0.1) )
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:30: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:74: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:76: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations

# %%
# 1) Question
# TODO: We have in total 660 images + 660 masks. Based on the code above,
# how many images are used for training alone?
#
# TODO: YOUR ANSWER

# %% [markdown]
# 462 images are been used for training.

# %%
#
# Let's setup the U-Net!
#
LEARNING_RATE = 1e-3

unet_model = unet.build_model(channels=channels,
                              num_classes=classes,
                              layer_depth=5,
                              filters_root=64,
                              padding="same")

unet.finalize_model(unet_model, learning_rate=LEARNING_RATE)

# %%
#
# And, let's setup the trainer...
#
trainer = unet.Trainer(checkpoint_callback=False,
                       learning_rate_scheduler=unet.SchedulerType.WARMUP_LINEAR_DECAY,
                       warmup_proportion=0.1,
                       learning_rate=LEARNING_RATE)

# %%
#
# ...and train the U-Net for 50 epochs with a batch_size of 10!
#
# TODO: Please complete the code below.
# Hint: Don't forget to use training and validation data.
# Hint 2: This will take roughly 30 minutes!
#
trainer.fit(unet_model,train,val,epochs=50,batch_size=10)
# Out:
# Epoch 1/50
# 47/47 [==============================] - 87s 1s/step - loss: 0.2832 - categorical_crossentropy: 0.2832 - categorical_accuracy: 0.8334 - mean_iou: 0.3538 - dice_coefficient: 0.7250 - auc: 0.9493 - learning_rate: 9.9911e-05 - val_loss: 0.2673 - val_categorical_crossentropy: 0.2673 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.3608 - val_dice_coefficient: 0.7312 - val_auc: 0.9939
# Epoch 2/50
# 47/47 [==============================] - 65s 1s/step - loss: 0.1277 - categorical_crossentropy: 0.1277 - categorical_accuracy: 0.9115 - mean_iou: 0.4041 - dice_coefficient: 0.8335 - auc: 0.9674 - learning_rate: 2.9991e-04 - val_loss: 0.2190 - val_categorical_crossentropy: 0.2190 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.3792 - val_dice_coefficient: 0.7698 - val_auc: 0.9932
# Epoch 3/50
# 47/47 [==============================] - 65s 1s/step - loss: 0.1024 - categorical_crossentropy: 0.1024 - categorical_accuracy: 0.9115 - mean_iou: 0.4143 - dice_coefficient: 0.8563 - auc: 0.9685 - learning_rate: 4.9991e-04 - val_loss: 0.1324 - val_categorical_crossentropy: 0.1324 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4138 - val_dice_coefficient: 0.8437 - val_auc: 0.9931
# Epoch 4/50
# 47/47 [==============================] - 65s 1s/step - loss: 0.0989 - categorical_crossentropy: 0.0989 - categorical_accuracy: 0.9115 - mean_iou: 0.4155 - dice_coefficient: 0.8589 - auc: 0.9697 - learning_rate: 6.9991e-04 - val_loss: 0.1290 - val_categorical_crossentropy: 0.1290 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4154 - val_dice_coefficient: 0.8469 - val_auc: 0.9935
# Epoch 5/50
# 47/47 [==============================] - 65s 1s/step - loss: 0.1027 - categorical_crossentropy: 0.1027 - categorical_accuracy: 0.9115 - mean_iou: 0.4144 - dice_coefficient: 0.8552 - auc: 0.9715 - learning_rate: 8.9991e-04 - val_loss: 0.1369 - val_categorical_crossentropy: 0.1369 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4125 - val_dice_coefficient: 0.8401 - val_auc: 0.9935
# Epoch 6/50
# 47/47 [==============================] - 65s 1s/step - loss: 0.0970 - categorical_crossentropy: 0.0970 - categorical_accuracy: 0.9115 - mean_iou: 0.4169 - dice_coefficient: 0.8608 - auc: 0.9721 - learning_rate: 9.8890e-04 - val_loss: 0.1343 - val_categorical_crossentropy: 0.1343 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4139 - val_dice_coefficient: 0.8428 - val_auc: 0.9936
# Epoch 7/50
# 47/47 [==============================] - 65s 1s/step - loss: 0.0948 - categorical_crossentropy: 0.0948 - categorical_accuracy: 0.9115 - mean_iou: 0.4180 - dice_coefficient: 0.8630 - auc: 0.9736 - learning_rate: 9.6668e-04 - val_loss: 0.1150 - val_categorical_crossentropy: 0.1150 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4224 - val_dice_coefficient: 0.8605 - val_auc: 0.9938
# Epoch 8/50
# 47/47 [==============================] - 65s 1s/step - loss: 0.0902 - categorical_crossentropy: 0.0902 - categorical_accuracy: 0.9115 - mean_iou: 0.4203 - dice_coefficient: 0.8671 - auc: 0.9764 - learning_rate: 9.4445e-04 - val_loss: 0.1191 - val_categorical_crossentropy: 0.1191 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4215 - val_dice_coefficient: 0.8577 - val_auc: 0.9939
# Epoch 9/50
# 47/47 [==============================] - 65s 1s/step - loss: 0.0904 - categorical_crossentropy: 0.0904 - categorical_accuracy: 0.9115 - mean_iou: 0.4209 - dice_coefficient: 0.8673 - auc: 0.9781 - learning_rate: 9.2223e-04 - val_loss: 0.1218 - val_categorical_crossentropy: 0.1218 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4214 - val_dice_coefficient: 0.8563 - val_auc: 0.9941
# Epoch 10/50
# 47/47 [==============================] - 65s 1s/step - loss: 0.0875 - categorical_crossentropy: 0.0875 - categorical_accuracy: 0.9115 - mean_iou: 0.4227 - dice_coefficient: 0.8702 - auc: 0.9805 - learning_rate: 9.0001e-04 - val_loss: 0.1311 - val_categorical_crossentropy: 0.1311 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4187 - val_dice_coefficient: 0.8495 - val_auc: 0.9942
# Epoch 11/50
# 47/47 [==============================] - 65s 1s/step - loss: 0.0888 - categorical_crossentropy: 0.0888 - categorical_accuracy: 0.9115 - mean_iou: 0.4229 - dice_coefficient: 0.8698 - auc: 0.9813 - learning_rate: 8.7779e-04 - val_loss: 0.1258 - val_categorical_crossentropy: 0.1258 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4218 - val_dice_coefficient: 0.8553 - val_auc: 0.9943
# Epoch 12/50
# 47/47 [==============================] - 65s 1s/step - loss: 0.0874 - categorical_crossentropy: 0.0874 - categorical_accuracy: 0.9115 - mean_iou: 0.4241 - dice_coefficient: 0.8715 - auc: 0.9830 - learning_rate: 8.5557e-04 - val_loss: 0.1260 - val_categorical_crossentropy: 0.1260 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4227 - val_dice_coefficient: 0.8563 - val_auc: 0.9944
# Epoch 13/50
# 47/47 [==============================] - 65s 1s/step - loss: 0.0864 - categorical_crossentropy: 0.0864 - categorical_accuracy: 0.9115 - mean_iou: 0.4253 - dice_coefficient: 0.8729 - auc: 0.9844 - learning_rate: 8.3334e-04 - val_loss: 0.1249 - val_categorical_crossentropy: 0.1249 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4242 - val_dice_coefficient: 0.8585 - val_auc: 0.9945
# Epoch 14/50
# 47/47 [==============================] - 66s 1s/step - loss: 0.0859 - categorical_crossentropy: 0.0859 - categorical_accuracy: 0.9115 - mean_iou: 0.4262 - dice_coefficient: 0.8740 - auc: 0.9855 - learning_rate: 8.1112e-04 - val_loss: 0.1215 - val_categorical_crossentropy: 0.1215 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4265 - val_dice_coefficient: 0.8625 - val_auc: 0.9946
# Epoch 15/50
# 47/47 [==============================] - 66s 1s/step - loss: 0.0848 - categorical_crossentropy: 0.0848 - categorical_accuracy: 0.9115 - mean_iou: 0.4273 - dice_coefficient: 0.8754 - auc: 0.9866 - learning_rate: 7.8890e-04 - val_loss: 0.1212 - val_categorical_crossentropy: 0.1212 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4275 - val_dice_coefficient: 0.8639 - val_auc: 0.9947
# Epoch 16/50
# 47/47 [==============================] - 66s 1s/step - loss: 0.0836 - categorical_crossentropy: 0.0836 - categorical_accuracy: 0.9115 - mean_iou: 0.4284 - dice_coefficient: 0.8768 - auc: 0.9875 - learning_rate: 7.6668e-04 - val_loss: 0.1202 - val_categorical_crossentropy: 0.1202 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4284 - val_dice_coefficient: 0.8654 - val_auc: 0.9948
# Epoch 17/50
# 47/47 [==============================] - 66s 1s/step - loss: 0.0827 - categorical_crossentropy: 0.0827 - categorical_accuracy: 0.9115 - mean_iou: 0.4292 - dice_coefficient: 0.8780 - auc: 0.9882 - learning_rate: 7.4445e-04 - val_loss: 0.1155 - val_categorical_crossentropy: 0.1155 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4307 - val_dice_coefficient: 0.8700 - val_auc: 0.9948
# Epoch 18/50
# 47/47 [==============================] - 66s 1s/step - loss: 0.0814 - categorical_crossentropy: 0.0814 - categorical_accuracy: 0.9115 - mean_iou: 0.4303 - dice_coefficient: 0.8794 - auc: 0.9889 - learning_rate: 7.2223e-04 - val_loss: 0.1193 - val_categorical_crossentropy: 0.1193 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4297 - val_dice_coefficient: 0.8674 - val_auc: 0.9950
# Epoch 19/50
# 47/47 [==============================] - 66s 1s/step - loss: 0.0814 - categorical_crossentropy: 0.0814 - categorical_accuracy: 0.9115 - mean_iou: 0.4307 - dice_coefficient: 0.8797 - auc: 0.9892 - learning_rate: 7.0001e-04 - val_loss: 0.1095 - val_categorical_crossentropy: 0.1095 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4336 - val_dice_coefficient: 0.8756 - val_auc: 0.9951
# Epoch 20/50
# 47/47 [==============================] - 66s 1s/step - loss: 0.0796 - categorical_crossentropy: 0.0796 - categorical_accuracy: 0.9115 - mean_iou: 0.4317 - dice_coefficient: 0.8814 - auc: 0.9898 - learning_rate: 6.7779e-04 - val_loss: 0.1024 - val_categorical_crossentropy: 0.1024 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4364 - val_dice_coefficient: 0.8815 - val_auc: 0.9952
# Epoch 21/50
# 47/47 [==============================] - 66s 1s/step - loss: 0.0774 - categorical_crossentropy: 0.0774 - categorical_accuracy: 0.9115 - mean_iou: 0.4329 - dice_coefficient: 0.8835 - auc: 0.9904 - learning_rate: 6.5557e-04 - val_loss: 0.1045 - val_categorical_crossentropy: 0.1045 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4360 - val_dice_coefficient: 0.8803 - val_auc: 0.9953
# Epoch 22/50
# 47/47 [==============================] - 66s 1s/step - loss: 0.0775 - categorical_crossentropy: 0.0775 - categorical_accuracy: 0.9115 - mean_iou: 0.4333 - dice_coefficient: 0.8835 - auc: 0.9907 - learning_rate: 6.3334e-04 - val_loss: 0.1051 - val_categorical_crossentropy: 0.1051 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4360 - val_dice_coefficient: 0.8801 - val_auc: 0.9954
# Epoch 23/50
# 47/47 [==============================] - 66s 1s/step - loss: 0.0772 - categorical_crossentropy: 0.0772 - categorical_accuracy: 0.9115 - mean_iou: 0.4336 - dice_coefficient: 0.8841 - auc: 0.9909 - learning_rate: 6.1112e-04 - val_loss: 0.0905 - val_categorical_crossentropy: 0.0905 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4413 - val_dice_coefficient: 0.8918 - val_auc: 0.9954
# Epoch 24/50
# 47/47 [==============================] - 66s 1s/step - loss: 0.0737 - categorical_crossentropy: 0.0737 - categorical_accuracy: 0.9115 - mean_iou: 0.4351 - dice_coefficient: 0.8871 - auc: 0.9914 - learning_rate: 5.8890e-04 - val_loss: 0.0942 - val_categorical_crossentropy: 0.0942 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4402 - val_dice_coefficient: 0.8890 - val_auc: 0.9955
# Epoch 25/50
# 47/47 [==============================] - 65s 1s/step - loss: 0.0722 - categorical_crossentropy: 0.0722 - categorical_accuracy: 0.9115 - mean_iou: 0.4360 - dice_coefficient: 0.8885 - auc: 0.9918 - learning_rate: 5.6668e-04 - val_loss: 0.0938 - val_categorical_crossentropy: 0.0938 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4405 - val_dice_coefficient: 0.8894 - val_auc: 0.9958
# Epoch 26/50
# 47/47 [==============================] - 66s 1s/step - loss: 0.0714 - categorical_crossentropy: 0.0714 - categorical_accuracy: 0.9115 - mean_iou: 0.4367 - dice_coefficient: 0.8891 - auc: 0.9922 - learning_rate: 5.4445e-04 - val_loss: 0.1073 - val_categorical_crossentropy: 0.1073 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4360 - val_dice_coefficient: 0.8791 - val_auc: 0.9957
# Epoch 27/50
# 47/47 [==============================] - 65s 1s/step - loss: 0.0745 - categorical_crossentropy: 0.0745 - categorical_accuracy: 0.9115 - mean_iou: 0.4357 - dice_coefficient: 0.8871 - auc: 0.9919 - learning_rate: 5.2223e-04 - val_loss: 0.0821 - val_categorical_crossentropy: 0.0821 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4451 - val_dice_coefficient: 0.8993 - val_auc: 0.9957
# Epoch 28/50
# 47/47 [==============================] - 66s 1s/step - loss: 0.0698 - categorical_crossentropy: 0.0698 - categorical_accuracy: 0.9115 - mean_iou: 0.4377 - dice_coefficient: 0.8910 - auc: 0.9924 - learning_rate: 5.0001e-04 - val_loss: 0.0827 - val_categorical_crossentropy: 0.0827 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4452 - val_dice_coefficient: 0.8991 - val_auc: 0.9957
# Epoch 29/50
# 47/47 [==============================] - 66s 1s/step - loss: 0.0697 - categorical_crossentropy: 0.0697 - categorical_accuracy: 0.9115 - mean_iou: 0.4381 - dice_coefficient: 0.8912 - auc: 0.9926 - learning_rate: 4.7779e-04 - val_loss: 0.0834 - val_categorical_crossentropy: 0.0834 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4451 - val_dice_coefficient: 0.8986 - val_auc: 0.9959
# Epoch 30/50
# 47/47 [==============================] - 66s 1s/step - loss: 0.0666 - categorical_crossentropy: 0.0666 - categorical_accuracy: 0.9116 - mean_iou: 0.4395 - dice_coefficient: 0.8939 - auc: 0.9929 - learning_rate: 4.5557e-04 - val_loss: 0.0890 - val_categorical_crossentropy: 0.0890 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4438 - val_dice_coefficient: 0.8947 - val_auc: 0.9961
# Epoch 31/50
# 47/47 [==============================] - 66s 1s/step - loss: 0.0674 - categorical_crossentropy: 0.0674 - categorical_accuracy: 0.9139 - mean_iou: 0.4399 - dice_coefficient: 0.8934 - auc: 0.9931 - learning_rate: 4.3334e-04 - val_loss: 0.1024 - val_categorical_crossentropy: 0.1024 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4394 - val_dice_coefficient: 0.8845 - val_auc: 0.9961
# Epoch 32/50
# 47/47 [==============================] - 66s 1s/step - loss: 0.0688 - categorical_crossentropy: 0.0688 - categorical_accuracy: 0.9161 - mean_iou: 0.4398 - dice_coefficient: 0.8926 - auc: 0.9931 - learning_rate: 4.1112e-04 - val_loss: 0.0924 - val_categorical_crossentropy: 0.0924 - val_categorical_accuracy: 0.9422 - val_mean_iou: 0.4434 - val_dice_coefficient: 0.8929 - val_auc: 0.9957
# Epoch 33/50
# 47/47 [==============================] - 65s 1s/step - loss: 0.0620 - categorical_crossentropy: 0.0620 - categorical_accuracy: 0.9207 - mean_iou: 0.4428 - dice_coefficient: 0.8982 - auc: 0.9938 - learning_rate: 3.8890e-04 - val_loss: 0.1039 - val_categorical_crossentropy: 0.1039 - val_categorical_accuracy: 0.9299 - val_mean_iou: 0.4404 - val_dice_coefficient: 0.8848 - val_auc: 0.9945
# Epoch 34/50
# 47/47 [==============================] - 65s 1s/step - loss: 0.0622 - categorical_crossentropy: 0.0622 - categorical_accuracy: 0.9254 - mean_iou: 0.4437 - dice_coefficient: 0.8987 - auc: 0.9937 - learning_rate: 3.6668e-04 - val_loss: 0.1125 - val_categorical_crossentropy: 0.1125 - val_categorical_accuracy: 0.9242 - val_mean_iou: 0.4374 - val_dice_coefficient: 0.8783 - val_auc: 0.9938
# Epoch 35/50
# 47/47 [==============================] - 66s 1s/step - loss: 0.0581 - categorical_crossentropy: 0.0581 - categorical_accuracy: 0.9288 - mean_iou: 0.4459 - dice_coefficient: 0.9024 - auc: 0.9942 - learning_rate: 3.4445e-04 - val_loss: 0.1075 - val_categorical_crossentropy: 0.1075 - val_categorical_accuracy: 0.9201 - val_mean_iou: 0.4399 - val_dice_coefficient: 0.8829 - val_auc: 0.9933
# Epoch 36/50
# 47/47 [==============================] - 66s 1s/step - loss: 0.0543 - categorical_crossentropy: 0.0543 - categorical_accuracy: 0.9323 - mean_iou: 0.4484 - dice_coefficient: 0.9062 - auc: 0.9948 - learning_rate: 3.2223e-04 - val_loss: 0.1088 - val_categorical_crossentropy: 0.1088 - val_categorical_accuracy: 0.9142 - val_mean_iou: 0.4400 - val_dice_coefficient: 0.8826 - val_auc: 0.9924
# Epoch 37/50
# 47/47 [==============================] - 66s 1s/step - loss: 0.0533 - categorical_crossentropy: 0.0533 - categorical_accuracy: 0.9337 - mean_iou: 0.4494 - dice_coefficient: 0.9076 - auc: 0.9948 - learning_rate: 3.0001e-04 - val_loss: 0.0993 - val_categorical_crossentropy: 0.0993 - val_categorical_accuracy: 0.9200 - val_mean_iou: 0.4438 - val_dice_coefficient: 0.8901 - val_auc: 0.9932
# Epoch 38/50
# 47/47 [==============================] - 65s 1s/step - loss: 0.0498 - categorical_crossentropy: 0.0498 - categorical_accuracy: 0.9370 - mean_iou: 0.4515 - dice_coefficient: 0.9109 - auc: 0.9953 - learning_rate: 2.7779e-04 - val_loss: 0.0930 - val_categorical_crossentropy: 0.0930 - val_categorical_accuracy: 0.9227 - val_mean_iou: 0.4465 - val_dice_coefficient: 0.8954 - val_auc: 0.9934
# Epoch 39/50
# 47/47 [==============================] - 66s 1s/step - loss: 0.0478 - categorical_crossentropy: 0.0478 - categorical_accuracy: 0.9402 - mean_iou: 0.4529 - dice_coefficient: 0.9130 - auc: 0.9955 - learning_rate: 2.5557e-04 - val_loss: 0.0869 - val_categorical_crossentropy: 0.0869 - val_categorical_accuracy: 0.9264 - val_mean_iou: 0.4490 - val_dice_coefficient: 0.9003 - val_auc: 0.9938
# Epoch 40/50
# 47/47 [==============================] - 65s 1s/step - loss: 0.0458 - categorical_crossentropy: 0.0458 - categorical_accuracy: 0.9431 - mean_iou: 0.4541 - dice_coefficient: 0.9149 - auc: 0.9957 - learning_rate: 2.3334e-04 - val_loss: 0.0787 - val_categorical_crossentropy: 0.0787 - val_categorical_accuracy: 0.9324 - val_mean_iou: 0.4521 - val_dice_coefficient: 0.9067 - val_auc: 0.9946
# Epoch 41/50
# 47/47 [==============================] - 64s 1s/step - loss: 0.0440 - categorical_crossentropy: 0.0440 - categorical_accuracy: 0.9453 - mean_iou: 0.4550 - dice_coefficient: 0.9165 - auc: 0.9959 - learning_rate: 2.1112e-04 - val_loss: 0.0727 - val_categorical_crossentropy: 0.0727 - val_categorical_accuracy: 0.9370 - val_mean_iou: 0.4544 - val_dice_coefficient: 0.9114 - val_auc: 0.9951
# Epoch 42/50
# 47/47 [==============================] - 65s 1s/step - loss: 0.0422 - categorical_crossentropy: 0.0422 - categorical_accuracy: 0.9472 - mean_iou: 0.4560 - dice_coefficient: 0.9181 - auc: 0.9961 - learning_rate: 1.8890e-04 - val_loss: 0.0698 - val_categorical_crossentropy: 0.0698 - val_categorical_accuracy: 0.9390 - val_mean_iou: 0.4556 - val_dice_coefficient: 0.9137 - val_auc: 0.9953
# Epoch 43/50
# 47/47 [==============================] - 65s 1s/step - loss: 0.0409 - categorical_crossentropy: 0.0409 - categorical_accuracy: 0.9492 - mean_iou: 0.4566 - dice_coefficient: 0.9192 - auc: 0.9963 - learning_rate: 1.6668e-04 - val_loss: 0.0664 - val_categorical_crossentropy: 0.0664 - val_categorical_accuracy: 0.9420 - val_mean_iou: 0.4569 - val_dice_coefficient: 0.9163 - val_auc: 0.9957
# Epoch 44/50
# 47/47 [==============================] - 65s 1s/step - loss: 0.0393 - categorical_crossentropy: 0.0393 - categorical_accuracy: 0.9506 - mean_iou: 0.4574 - dice_coefficient: 0.9205 - auc: 0.9965 - learning_rate: 1.4445e-04 - val_loss: 0.0672 - val_categorical_crossentropy: 0.0672 - val_categorical_accuracy: 0.9420 - val_mean_iou: 0.4566 - val_dice_coefficient: 0.9157 - val_auc: 0.9956
# Epoch 45/50
# 47/47 [==============================] - 65s 1s/step - loss: 0.0382 - categorical_crossentropy: 0.0382 - categorical_accuracy: 0.9524 - mean_iou: 0.4579 - dice_coefficient: 0.9214 - auc: 0.9966 - learning_rate: 1.2223e-04 - val_loss: 0.0649 - val_categorical_crossentropy: 0.0649 - val_categorical_accuracy: 0.9438 - val_mean_iou: 0.4574 - val_dice_coefficient: 0.9174 - val_auc: 0.9958
# Epoch 46/50
# 47/47 [==============================] - 65s 1s/step - loss: 0.0367 - categorical_crossentropy: 0.0367 - categorical_accuracy: 0.9542 - mean_iou: 0.4586 - dice_coefficient: 0.9227 - auc: 0.9968 - learning_rate: 1.0001e-04 - val_loss: 0.0652 - val_categorical_crossentropy: 0.0652 - val_categorical_accuracy: 0.9449 - val_mean_iou: 0.4573 - val_dice_coefficient: 0.9171 - val_auc: 0.9959
# Epoch 47/50
# 47/47 [==============================] - 65s 1s/step - loss: 0.0348 - categorical_crossentropy: 0.0348 - categorical_accuracy: 0.9560 - mean_iou: 0.4594 - dice_coefficient: 0.9242 - auc: 0.9970 - learning_rate: 7.7788e-05 - val_loss: 0.0671 - val_categorical_crossentropy: 0.0671 - val_categorical_accuracy: 0.9450 - val_mean_iou: 0.4566 - val_dice_coefficient: 0.9155 - val_auc: 0.9959
# Epoch 48/50
# 47/47 [==============================] - 65s 1s/step - loss: 0.0332 - categorical_crossentropy: 0.0332 - categorical_accuracy: 0.9582 - mean_iou: 0.4602 - dice_coefficient: 0.9256 - auc: 0.9972 - learning_rate: 5.5565e-05 - val_loss: 0.0656 - val_categorical_crossentropy: 0.0656 - val_categorical_accuracy: 0.9475 - val_mean_iou: 0.4571 - val_dice_coefficient: 0.9165 - val_auc: 0.9962
# Epoch 49/50
# 47/47 [==============================] - 66s 1s/step - loss: 0.0316 - categorical_crossentropy: 0.0316 - categorical_accuracy: 0.9608 - mean_iou: 0.4612 - dice_coefficient: 0.9270 - auc: 0.9973 - learning_rate: 3.3343e-05 - val_loss: 0.0628 - val_categorical_crossentropy: 0.0628 - val_categorical_accuracy: 0.9509 - val_mean_iou: 0.4581 - val_dice_coefficient: 0.9185 - val_auc: 0.9965
# Epoch 50/50
# 47/47 [==============================] - 65s 1s/step - loss: 0.0296 - categorical_crossentropy: 0.0296 - categorical_accuracy: 0.9630 - mean_iou: 0.4621 - dice_coefficient: 0.9286 - auc: 0.9975 - learning_rate: 1.1121e-05 - val_loss: 0.0621 - val_categorical_crossentropy: 0.0621 - val_categorical_accuracy: 0.9520 - val_mean_iou: 0.4583 - val_dice_coefficient: 0.9190 - val_auc: 0.9966

# %% [markdown]
# **Task 4**: Let's predict mitochondria in the testing data! [15 Points]

# %%
# 
# After training, let's try the U-Net on our testing data.
#
# The code below displays the first 10 input images, the original masks by experts, 
# and the predicted masks from the U-Net.

# %%
rows = 10
fig, axs = plt.subplots(rows, 3, figsize=(8, 30))
for ax, (image, label) in zip(axs, test.take(rows).batch(1)):
  
  prediction = unet_model.predict(image)
  ax[0].matshow(image[0, :, :, 0])
  ax[1].matshow(label[0, :, :, 1], cmap="gray")
  ax[2].matshow(prediction[0].argmax(axis=-1), cmap="gray")

# %%
# 1) Question
# TODO: Why do we use the prediction[0].argmax(axis=-1) command
# to display the prediction?
# 
# TODO: YOUR ANSWER

# %%
prediction.shape
# Out:
# (1, 256, 256, 2)

# %% [markdown]
# prediction gives us an array of shape (1,256,256,2) and the prediction[0] gives predicted image array and The prediction[0].argmax(axis=-1) function in numpy returns us the actual image array of dimension (256,256).

# %%
# 2) Question
# TODO: Is the quality of the segmentation good and how could we improve it?
# Hint: Think along the lines of some traditional image processing rather than
# increasing the training data size.
#
# TODO: YOUR ANSWER

# %% [markdown]
# segementation can be improved by using:
# 1.set a threshold and eliminate all the predicted masks which are less than that.
#
# 2.Improving contrast of the images by adaptive histogram equalization.

# %% [markdown]
# **Bonus**: Compare against the state-of-the-art literature! [33 Points]

# %%
#
# The following paper also uses a 2D U-Net to detect mitochondria:
# 
# https://danielhaehn.com/papers/?casser2020fast
#

# %%
# 1) Question
#
# TODO: How many learnable parameters does your trained unet_model have?
# Hint: You can use TF's Model Summary function to answer this.
#

# %%
unet_model.summary()
# Out:
# Model: "unet"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  inputs (InputLayer)            [(None, None, None,  0           []
#                                  1)]
#
#  conv_block (ConvBlock)         (None, None, None,   37568       ['inputs[0][0]']
#                                 64)
#
#  max_pooling2d (MaxPooling2D)   (None, None, None,   0           ['conv_block[0][0]']
#                                 64)
#
#  conv_block_1 (ConvBlock)       (None, None, None,   221440      ['max_pooling2d[0][0]']
#                                 128)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, None, None,   0          ['conv_block_1[0][0]']
#                                 128)
#
#  conv_block_2 (ConvBlock)       (None, None, None,   885248      ['max_pooling2d_1[0][0]']
#                                 256)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, None, None,   0          ['conv_block_2[0][0]']
#                                 256)
#
#  conv_block_3 (ConvBlock)       (None, None, None,   3539968     ['max_pooling2d_2[0][0]']
#                                 512)
#
#  max_pooling2d_3 (MaxPooling2D)  (None, None, None,   0          ['conv_block_3[0][0]']
#                                 512)
#
#  conv_block_4 (ConvBlock)       (None, None, None,   14157824    ['max_pooling2d_3[0][0]']
#                                 1024)
#
#  upconv_block (UpconvBlock)     (None, None, None,   2097664     ['conv_block_4[0][0]']
#                                 512)
#
#  crop_concat_block (CropConcatB  (None, None, None,   0          ['upconv_block[0][0]',
#  lock)                          1024)                             'conv_block_3[0][0]']
#
#  conv_block_5 (ConvBlock)       (None, None, None,   7078912     ['crop_concat_block[0][0]']
#                                 512)
#
#  upconv_block_1 (UpconvBlock)   (None, None, None,   524544      ['conv_block_5[0][0]']
#                                 256)
#
#  crop_concat_block_1 (CropConca  (None, None, None,   0          ['upconv_block_1[0][0]',
#  tBlock)                        512)                              'conv_block_2[0][0]']
#
#  conv_block_6 (ConvBlock)       (None, None, None,   1769984     ['crop_concat_block_1[0][0]']
#                                 256)
#
#  upconv_block_2 (UpconvBlock)   (None, None, None,   131200      ['conv_block_6[0][0]']
#                                 128)
#
#  crop_concat_block_2 (CropConca  (None, None, None,   0          ['upconv_block_2[0][0]',
#  tBlock)                        256)                              'conv_block_1[0][0]']
#
#  conv_block_7 (ConvBlock)       (None, None, None,   442624      ['crop_concat_block_2[0][0]']
#                                 128)
#
#  upconv_block_3 (UpconvBlock)   (None, None, None,   32832       ['conv_block_7[0][0]']
#                                 64)
#
#  crop_concat_block_3 (CropConca  (None, None, None,   0          ['upconv_block_3[0][0]',
#  tBlock)                        128)                              'conv_block[0][0]']
#
#  conv_block_8 (ConvBlock)       (None, None, None,   110720      ['crop_concat_block_3[0][0]']
#                                 64)
#
#  conv2d_18 (Conv2D)             (None, None, None,   130         ['conv_block_8[0][0]']
#                                 2)
#
#  activation_22 (Activation)     (None, None, None,   0           ['conv2d_18[0][0]']
#                                 2)
#
#  outputs (Activation)           (None, None, None,   0           ['activation_22[0][0]']
#                                 2)
#
# ==================================================================================================
# Total params: 31,030,658
# Trainable params: 31,030,658
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# 2) Question
#
# TODO: How many parameters do Casser et al. use?
#

# %%
# TODO: YOUR ANSWER

# %%
1,958,533 parameters are used by casser et al.

# %%
# 3) Question
#
# TODO: How did Casser et al. reduce the parameters?
#

# %%
# TODO: YOUR ANSWER

# %% [markdown]
# 1.Reducing the number of convolutional filters throughout the network.
# 2.Replacing transpose convolutions in the decoder with light-weight bilinear upsampling layers

# %%
# 4) Question
#
# TODO: Why did Casser et al. reduce the parameters?
#

# %%
# TODO: YOUR ANSWER

# %% [markdown]
# Casser et al. reduced the number of parameters to reduce the processing time and to avoid waiting for computationally expensive pre-alignment procedure. Reducing the parameters also resulted in an increase in the throughput of the model by 40%.

# %%
#
# You made it!!
#
#                 _ ___                /^^\ /^\  /^^\_
#     _          _@)@) \            ,,/ '` ~ `'~~ ', `\.
#   _/o\_ _ _ _/~`.`...'~\        ./~~..,'`','',.,' '  ~:
#  / `,'.~,~.~  .   , . , ~|,   ,/ .,' , ,. .. ,,.   `,  ~\_
# ( ' _' _ '_` _  '  .    , `\_/ .' ..' '  `  `   `..  `,   \_
#  ~V~ V~ V~ V~ ~\ `   ' .  '    , ' .,.,''`.,.''`.,.``. ',   \_
#   _/\ /\ /\ /\_/, . ' ,   `_/~\_ .' .,. ,, , _/~\_ `. `. '.,  \_
#  < ~ ~ '~`'~'`, .,  .   `_: ::: \_ '      `_/ ::: \_ `.,' . ',  \_
#   \ ' `_  '`_    _    ',/ _::_::_ \ _    _/ _::_::_ \   `.,'.,`., \-,-,-,_,_,
#    `'~~ `'~~ `'~~ `'~~  \(_)(_)(_)/  `~~' \(_)(_)(_)/ ~'`\_.._,._,'_;_;_;_;_;
#
