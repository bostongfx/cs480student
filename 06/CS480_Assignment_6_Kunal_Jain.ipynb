# %% [markdown]
# <a href="https://colab.research.google.com/github/jainkhere/cs480student/blob/main/06/CS480_Assignment_6_Kunal_Jain.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![CS480_w.png](data:image/png;base64,...)
# #Assignment 6

# %%
# In this assignment, we will train a U-Net classifer to detect mitochondria
# in electron microscopy images!

# %%
### IMPORTANT ###
#
# Activate GPU support: Runtime -> Change Runtime Type
# Hardware Accelerator: GPU
#
### IMPORTANT ###

# %%
# load numpy and matplotlib
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# load the unet tensorflow code
# !pip install git+https://github.com/jakeret/unet.git
# Out:
# Collecting git+https://github.com/jakeret/unet.git
#   Cloning https://github.com/jakeret/unet.git to /tmp/pip-req-build-ey2a4_rf
#   Running command git clone -q https://github.com/jakeret/unet.git /tmp/pip-req-build-ey2a4_rf
# Building wheels for collected packages: unet
#   Building wheel for unet (setup.py) ... done
#   Created wheel for unet: filename=unet-0.0.post0.dev81+gf557a51-py2.py3-none-any.whl size=25688 sha256=3cad1c2995baea0e475b71d63100870cf168b4ba988cf028d3e71d2deb3d8a5e
#   Stored in directory: /tmp/pip-ephem-wheel-cache-neu5ka40/wheels/22/00/93/ce57529ed355f160088cbb6ce086e55168770913b40cf624ba
# Successfully built unet
# Installing collected packages: unet
# Successfully installed unet-0.0.post0.dev81+gf557a51

# %%
# .. and use it!
# Note: There are a ton of U-Net implementations but this one is easier to use!
import unet

# %% [markdown]
# **Task 1**: Study the unet circle example and learn about mitochondria! [15 Points]

# %%
# The unet package allows to train a U-Net classifier with little code.
# As discussed in class, the U-Net can be used to label/segment/annotate images.

# %%
# TODO: Please study the Circles example 
# https://github.com/jakeret/unet/blob/master/notebooks/circles.ipynb

# %%
# TODO: ... and look how the (artificial) dataset is generated
# https://github.com/jakeret/unet/blob/master/src/unet/datasets/circles.py

# %%
# 1) Question
# TODO: Please describe what the U-Net is trained to do.
#
# TODO: YOUR ANSWER

# U-Net is trained to detect circles in a noisy image

# %%
# 2) Question
# TODO: In circles.py, what does the following mean:
#     channels = 1
#     classes = 2
#
# TODO: YOUR ANSWER

# Channels -> 
# Classes -> 2 classes, one for circle which is foreground and other for background.

# %%
# 3) Question
# TODO: What are mitochondria and what is their appearance in
# electron microscopy data?
# Hint: You can validate your answer in Task 4!
#
# TODO: YOUR ANSWER

# Mitochondria is an organelle the power house of a cell. It appears like rounded or sausage like structure.

# %% [markdown]
# **Task 2**: Setup a datagenerator for mitochondria images! [45 Points]

# %%
# TODO: 
# Download https://cs480.org/data/mito.npz to your computer.
# Then, please upload mito.npz using the file panel on the left.

# %%
# The code below is similar to the circles.py file from Task 1.
# We follow Tensorflow conventions to design a tf.data.Dataset for training
# the U-Net.
#
# TODO: Please add four different data augmentation methods in the code block
# below. (image normalization to 0..1, horizontal data flip, vertical data flip,
# rotation by 90 degrees)
#
# Hint: https://github.com/jakeret/unet/blob/master/src/unet/datasets/oxford_iiit_pet.py#L25

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import tensorflow as tf
import tensorflow_datasets as tfds
from tensorflow_datasets.core import DatasetInfo
from typing import Tuple, List

IMAGE_SIZE = (256, 256)
channels = 1
classes = 2

def load_data(count:int, splits:Tuple[float]=(0.7, 0.2, 0.1), **kwargs) -> List[tf.data.Dataset]:
    return [tf.data.Dataset.from_tensor_slices(_build_samples(int(split * count), **kwargs))
            for split in splits]


def _build_samples(sample_count:int, **kwargs) -> Tuple[np.array, np.array]:

    # here we load the mitochondria data
    loaded = np.load('/content/drive/MyDrive/CS480/mito.npz')
    loadedimages = loaded['arr_0'][0].copy()
    loadedmasks = loaded['arr_0'][1].copy()

    # now let's go to numpyland
    images = np.empty((sample_count, IMAGE_SIZE[0], IMAGE_SIZE[1], 1))
    labels = np.empty((sample_count, IMAGE_SIZE[0], IMAGE_SIZE[1], 2))
    for i in range(sample_count):
        image, mask = loadedimages[i], loadedmasks[i]

        image = image.reshape((IMAGE_SIZE[0], IMAGE_SIZE[1], 1)).astype(np.float)
        mask = mask.reshape((IMAGE_SIZE[0], IMAGE_SIZE[1], 1))

        #
        # TODO: Normalize the image to 0..1
        #
        # TODO: YOUR CODE
        image = tf.cast(image, tf.float32) / 255.0
        mask -= 1

        #
        # TODO: Use Tensorflow to flip the image horizontally
        #
        if tf.random.uniform(()) > 0.5:
            #
            # TODO: YOUR CODE
            #
            image = tf.image.flip_left_right(image)
            mask = tf.image.flip_left_right(mask)

        #
        # TODO: Use Tensorflow to flip the image vertically
        #
        if tf.random.uniform(()) > 0.5:
            #
            # TODO: YOUR CODE
            #
            image = tf.image.flip_up_down(image)
            mask = tf.image.flip_up_down(mask)

        #
        # TODO: Use Tensorflow to rotate the image 90 degrees
        #
        if tf.random.uniform(()) > 0.5:
            #
            # TODO: YOUR CODE
            #
            image = tf.image.rot90(image, k = 1, name=None)
            mask = tf.image.rot90(mask, k = 1, name=None)


        # augmentation done, let's store the image
        images[i] = image

        # here we split the mask to background and foreground
        fg = np.zeros((IMAGE_SIZE[0], IMAGE_SIZE[1], 1), dtype=np.bool)
        fg[mask == 255] = 1
        bg = np.zeros((IMAGE_SIZE[0], IMAGE_SIZE[1], 1), dtype=np.bool)
        bg[mask == 0] = 1
        
        labels[i, :, :, 0] = bg[:,:,0]
        labels[i, :, :, 1] = fg[:,:,0]

    return images, labels

# %% [markdown]
# **Task 3**: Let's train the U-Net! [25 Points]

# %%
#
# We can now create our training, validation, and testing data by calling
# our methods from Task 2.
#
train, val, test = load_data( 660, splits=(0.7, 0.2, 0.1) )
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:73: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:75: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations

# %%
# 1) Question
# TODO: We have in total 660 images + 660 masks. Based on the code above,
# how many images are used for training alone?
#
# TODO: YOUR ANSWER

# 70 percent of total images and mask are used for training. 
# 70 percent of 660 = 462 images and 462 masks

# %%
#
# Let's setup the U-Net!
#
LEARNING_RATE = 1e-3

unet_model = unet.build_model(channels=channels,
                              num_classes=classes,
                              layer_depth=5,
                              filters_root=64,
                              padding="same")

unet.finalize_model(unet_model, learning_rate=LEARNING_RATE)

# %%
#
# And, let's setup the trainer...
#
trainer = unet.Trainer(checkpoint_callback=False,
                       learning_rate_scheduler=unet.SchedulerType.WARMUP_LINEAR_DECAY,
                       warmup_proportion=0.1,
                       learning_rate=LEARNING_RATE)

# %%
#
# ...and train the U-Net for 50 epochs with a batch_size of 10!
#
# TODO: Please complete the code below.
# Hint: Don't forget to use training and validation data.
# Hint 2: This will take roughly 30 minutes!
#
trainer.fit(unet_model,
            #
            # TODO: YOUR CODE
            #
            #
            train,
            val,
            epochs=50,
            batch_size=10
            )
# Out:
# Epoch 1/50
# 47/47 [==============================] - 115s 2s/step - loss: 0.4777 - categorical_crossentropy: 0.4777 - categorical_accuracy: 0.6348 - mean_iou: 0.2894 - dice_coefficient: 0.5871 - auc: 0.8307 - learning_rate: 9.9911e-05 - val_loss: 0.2943 - val_categorical_crossentropy: 0.2943 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.3510 - val_dice_coefficient: 0.7106 - val_auc: 0.9938
# Epoch 2/50
# 47/47 [==============================] - 86s 2s/step - loss: 0.1135 - categorical_crossentropy: 0.1135 - categorical_accuracy: 0.9114 - mean_iou: 0.4117 - dice_coefficient: 0.8485 - auc: 0.9718 - learning_rate: 2.9991e-04 - val_loss: 0.2771 - val_categorical_crossentropy: 0.2771 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.3574 - val_dice_coefficient: 0.7238 - val_auc: 0.9933
# Epoch 3/50
# 47/47 [==============================] - 86s 2s/step - loss: 0.1102 - categorical_crossentropy: 0.1102 - categorical_accuracy: 0.9115 - mean_iou: 0.4111 - dice_coefficient: 0.8495 - auc: 0.9674 - learning_rate: 4.9991e-04 - val_loss: 0.1171 - val_categorical_crossentropy: 0.1171 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4201 - val_dice_coefficient: 0.8573 - val_auc: 0.9934
# Epoch 4/50
# 47/47 [==============================] - 86s 2s/step - loss: 0.1006 - categorical_crossentropy: 0.1006 - categorical_accuracy: 0.9115 - mean_iou: 0.4148 - dice_coefficient: 0.8571 - auc: 0.9696 - learning_rate: 6.9991e-04 - val_loss: 0.1346 - val_categorical_crossentropy: 0.1346 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4131 - val_dice_coefficient: 0.8419 - val_auc: 0.9933
# Epoch 5/50
# 47/47 [==============================] - 86s 2s/step - loss: 0.1009 - categorical_crossentropy: 0.1009 - categorical_accuracy: 0.9115 - mean_iou: 0.4153 - dice_coefficient: 0.8571 - auc: 0.9721 - learning_rate: 8.9991e-04 - val_loss: 0.1106 - val_categorical_crossentropy: 0.1106 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4232 - val_dice_coefficient: 0.8635 - val_auc: 0.9936
# Epoch 6/50
# 47/47 [==============================] - 86s 2s/step - loss: 0.0989 - categorical_crossentropy: 0.0989 - categorical_accuracy: 0.9115 - mean_iou: 0.4162 - dice_coefficient: 0.8588 - auc: 0.9727 - learning_rate: 9.8890e-04 - val_loss: 0.1416 - val_categorical_crossentropy: 0.1416 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4110 - val_dice_coefficient: 0.8364 - val_auc: 0.9937
# Epoch 7/50
# 47/47 [==============================] - 86s 2s/step - loss: 0.0975 - categorical_crossentropy: 0.0975 - categorical_accuracy: 0.9115 - mean_iou: 0.4171 - dice_coefficient: 0.8610 - auc: 0.9727 - learning_rate: 9.6668e-04 - val_loss: 0.1110 - val_categorical_crossentropy: 0.1110 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4239 - val_dice_coefficient: 0.8639 - val_auc: 0.9939
# Epoch 8/50
# 47/47 [==============================] - 86s 2s/step - loss: 0.0911 - categorical_crossentropy: 0.0911 - categorical_accuracy: 0.9115 - mean_iou: 0.4199 - dice_coefficient: 0.8663 - auc: 0.9762 - learning_rate: 9.4445e-04 - val_loss: 0.1142 - val_categorical_crossentropy: 0.1142 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4235 - val_dice_coefficient: 0.8619 - val_auc: 0.9940
# Epoch 9/50
# 47/47 [==============================] - 86s 2s/step - loss: 0.0908 - categorical_crossentropy: 0.0908 - categorical_accuracy: 0.9115 - mean_iou: 0.4206 - dice_coefficient: 0.8669 - auc: 0.9780 - learning_rate: 9.2223e-04 - val_loss: 0.1201 - val_categorical_crossentropy: 0.1201 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4221 - val_dice_coefficient: 0.8578 - val_auc: 0.9941
# Epoch 10/50
# 47/47 [==============================] - 86s 2s/step - loss: 0.0906 - categorical_crossentropy: 0.0906 - categorical_accuracy: 0.9115 - mean_iou: 0.4214 - dice_coefficient: 0.8676 - auc: 0.9794 - learning_rate: 9.0001e-04 - val_loss: 0.1236 - val_categorical_crossentropy: 0.1236 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4217 - val_dice_coefficient: 0.8559 - val_auc: 0.9942
# Epoch 11/50
# 47/47 [==============================] - 86s 2s/step - loss: 0.0895 - categorical_crossentropy: 0.0895 - categorical_accuracy: 0.9115 - mean_iou: 0.4226 - dice_coefficient: 0.8693 - auc: 0.9812 - learning_rate: 8.7779e-04 - val_loss: 0.1179 - val_categorical_crossentropy: 0.1179 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4250 - val_dice_coefficient: 0.8620 - val_auc: 0.9943
# Epoch 12/50
# 47/47 [==============================] - 85s 2s/step - loss: 0.0881 - categorical_crossentropy: 0.0881 - categorical_accuracy: 0.9115 - mean_iou: 0.4239 - dice_coefficient: 0.8709 - auc: 0.9830 - learning_rate: 8.5557e-04 - val_loss: 0.1187 - val_categorical_crossentropy: 0.1187 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4258 - val_dice_coefficient: 0.8627 - val_auc: 0.9944
# Epoch 13/50
# 47/47 [==============================] - 86s 2s/step - loss: 0.0867 - categorical_crossentropy: 0.0867 - categorical_accuracy: 0.9115 - mean_iou: 0.4252 - dice_coefficient: 0.8728 - auc: 0.9840 - learning_rate: 8.3334e-04 - val_loss: 0.1133 - val_categorical_crossentropy: 0.1133 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4287 - val_dice_coefficient: 0.8683 - val_auc: 0.9945
# Epoch 14/50
# 47/47 [==============================] - 86s 2s/step - loss: 0.0870 - categorical_crossentropy: 0.0870 - categorical_accuracy: 0.9115 - mean_iou: 0.4258 - dice_coefficient: 0.8730 - auc: 0.9853 - learning_rate: 8.1112e-04 - val_loss: 0.1169 - val_categorical_crossentropy: 0.1169 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4282 - val_dice_coefficient: 0.8664 - val_auc: 0.9945
# Epoch 15/50
# 47/47 [==============================] - 86s 2s/step - loss: 0.0864 - categorical_crossentropy: 0.0864 - categorical_accuracy: 0.9115 - mean_iou: 0.4268 - dice_coefficient: 0.8742 - auc: 0.9863 - learning_rate: 7.8890e-04 - val_loss: 0.1116 - val_categorical_crossentropy: 0.1116 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4311 - val_dice_coefficient: 0.8718 - val_auc: 0.9946
# Epoch 16/50
# 47/47 [==============================] - 86s 2s/step - loss: 0.0853 - categorical_crossentropy: 0.0853 - categorical_accuracy: 0.9115 - mean_iou: 0.4279 - dice_coefficient: 0.8755 - auc: 0.9873 - learning_rate: 7.6668e-04 - val_loss: 0.1113 - val_categorical_crossentropy: 0.1113 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4319 - val_dice_coefficient: 0.8729 - val_auc: 0.9947
# Epoch 17/50
# 47/47 [==============================] - 86s 2s/step - loss: 0.0840 - categorical_crossentropy: 0.0840 - categorical_accuracy: 0.9115 - mean_iou: 0.4289 - dice_coefficient: 0.8769 - auc: 0.9881 - learning_rate: 7.4445e-04 - val_loss: 0.1157 - val_categorical_crossentropy: 0.1157 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4307 - val_dice_coefficient: 0.8699 - val_auc: 0.9948
# Epoch 18/50
# 47/47 [==============================] - 86s 2s/step - loss: 0.0835 - categorical_crossentropy: 0.0835 - categorical_accuracy: 0.9115 - mean_iou: 0.4295 - dice_coefficient: 0.8778 - auc: 0.9884 - learning_rate: 7.2223e-04 - val_loss: 0.1013 - val_categorical_crossentropy: 0.1013 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4363 - val_dice_coefficient: 0.8820 - val_auc: 0.9949
# Epoch 19/50
# 47/47 [==============================] - 86s 2s/step - loss: 0.0823 - categorical_crossentropy: 0.0823 - categorical_accuracy: 0.9115 - mean_iou: 0.4305 - dice_coefficient: 0.8791 - auc: 0.9892 - learning_rate: 7.0001e-04 - val_loss: 0.1009 - val_categorical_crossentropy: 0.1009 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4367 - val_dice_coefficient: 0.8826 - val_auc: 0.9950
# Epoch 20/50
# 47/47 [==============================] - 86s 2s/step - loss: 0.0810 - categorical_crossentropy: 0.0810 - categorical_accuracy: 0.9115 - mean_iou: 0.4313 - dice_coefficient: 0.8804 - auc: 0.9897 - learning_rate: 6.7779e-04 - val_loss: 0.0992 - val_categorical_crossentropy: 0.0992 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4375 - val_dice_coefficient: 0.8842 - val_auc: 0.9952
# Epoch 21/50
# 47/47 [==============================] - 86s 2s/step - loss: 0.0792 - categorical_crossentropy: 0.0792 - categorical_accuracy: 0.9115 - mean_iou: 0.4323 - dice_coefficient: 0.8821 - auc: 0.9902 - learning_rate: 6.5557e-04 - val_loss: 0.0932 - val_categorical_crossentropy: 0.0932 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4399 - val_dice_coefficient: 0.8892 - val_auc: 0.9953
# Epoch 22/50
# 47/47 [==============================] - 86s 2s/step - loss: 0.0773 - categorical_crossentropy: 0.0773 - categorical_accuracy: 0.9115 - mean_iou: 0.4333 - dice_coefficient: 0.8838 - auc: 0.9907 - learning_rate: 6.3334e-04 - val_loss: 0.0921 - val_categorical_crossentropy: 0.0921 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4405 - val_dice_coefficient: 0.8903 - val_auc: 0.9954
# Epoch 23/50
# 47/47 [==============================] - 86s 2s/step - loss: 0.0758 - categorical_crossentropy: 0.0758 - categorical_accuracy: 0.9115 - mean_iou: 0.4341 - dice_coefficient: 0.8852 - auc: 0.9910 - learning_rate: 6.1112e-04 - val_loss: 0.0883 - val_categorical_crossentropy: 0.0883 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4421 - val_dice_coefficient: 0.8935 - val_auc: 0.9955
# Epoch 24/50
# 47/47 [==============================] - 86s 2s/step - loss: 0.0743 - categorical_crossentropy: 0.0743 - categorical_accuracy: 0.9115 - mean_iou: 0.4350 - dice_coefficient: 0.8867 - auc: 0.9914 - learning_rate: 5.8890e-04 - val_loss: 0.0859 - val_categorical_crossentropy: 0.0859 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4432 - val_dice_coefficient: 0.8957 - val_auc: 0.9956
# Epoch 25/50
# 47/47 [==============================] - 86s 2s/step - loss: 0.0731 - categorical_crossentropy: 0.0731 - categorical_accuracy: 0.9115 - mean_iou: 0.4357 - dice_coefficient: 0.8878 - auc: 0.9917 - learning_rate: 5.6668e-04 - val_loss: 0.0838 - val_categorical_crossentropy: 0.0838 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4441 - val_dice_coefficient: 0.8975 - val_auc: 0.9957
# Epoch 26/50
# 47/47 [==============================] - 86s 2s/step - loss: 0.0721 - categorical_crossentropy: 0.0721 - categorical_accuracy: 0.9115 - mean_iou: 0.4363 - dice_coefficient: 0.8888 - auc: 0.9919 - learning_rate: 5.4445e-04 - val_loss: 0.0808 - val_categorical_crossentropy: 0.0808 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4454 - val_dice_coefficient: 0.9001 - val_auc: 0.9957
# Epoch 27/50
# 47/47 [==============================] - 86s 2s/step - loss: 0.0711 - categorical_crossentropy: 0.0711 - categorical_accuracy: 0.9115 - mean_iou: 0.4369 - dice_coefficient: 0.8898 - auc: 0.9921 - learning_rate: 5.2223e-04 - val_loss: 0.0790 - val_categorical_crossentropy: 0.0790 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4462 - val_dice_coefficient: 0.9017 - val_auc: 0.9957
# Epoch 28/50
# 47/47 [==============================] - 86s 2s/step - loss: 0.0704 - categorical_crossentropy: 0.0704 - categorical_accuracy: 0.9115 - mean_iou: 0.4375 - dice_coefficient: 0.8905 - auc: 0.9923 - learning_rate: 5.0001e-04 - val_loss: 0.0767 - val_categorical_crossentropy: 0.0767 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4472 - val_dice_coefficient: 0.9038 - val_auc: 0.9958
# Epoch 29/50
# 47/47 [==============================] - 86s 2s/step - loss: 0.0697 - categorical_crossentropy: 0.0697 - categorical_accuracy: 0.9115 - mean_iou: 0.4380 - dice_coefficient: 0.8912 - auc: 0.9925 - learning_rate: 4.7779e-04 - val_loss: 0.0755 - val_categorical_crossentropy: 0.0755 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4478 - val_dice_coefficient: 0.9049 - val_auc: 0.9958
# Epoch 30/50
# 47/47 [==============================] - 86s 2s/step - loss: 0.0694 - categorical_crossentropy: 0.0694 - categorical_accuracy: 0.9115 - mean_iou: 0.4383 - dice_coefficient: 0.8917 - auc: 0.9926 - learning_rate: 4.5557e-04 - val_loss: 0.0737 - val_categorical_crossentropy: 0.0737 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4486 - val_dice_coefficient: 0.9065 - val_auc: 0.9959
# Epoch 31/50
# 47/47 [==============================] - 86s 2s/step - loss: 0.0687 - categorical_crossentropy: 0.0687 - categorical_accuracy: 0.9115 - mean_iou: 0.4388 - dice_coefficient: 0.8923 - auc: 0.9928 - learning_rate: 4.3334e-04 - val_loss: 0.0725 - val_categorical_crossentropy: 0.0725 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4492 - val_dice_coefficient: 0.9076 - val_auc: 0.9959
# Epoch 32/50
# 47/47 [==============================] - 86s 2s/step - loss: 0.0661 - categorical_crossentropy: 0.0661 - categorical_accuracy: 0.9118 - mean_iou: 0.4402 - dice_coefficient: 0.8945 - auc: 0.9932 - learning_rate: 4.1112e-04 - val_loss: 0.0819 - val_categorical_crossentropy: 0.0819 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4464 - val_dice_coefficient: 0.9005 - val_auc: 0.9959
# Epoch 33/50
# 47/47 [==============================] - 86s 2s/step - loss: 0.0694 - categorical_crossentropy: 0.0694 - categorical_accuracy: 0.9122 - mean_iou: 0.4391 - dice_coefficient: 0.8922 - auc: 0.9929 - learning_rate: 3.8890e-04 - val_loss: 0.0703 - val_categorical_crossentropy: 0.0703 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4505 - val_dice_coefficient: 0.9098 - val_auc: 0.9960
# Epoch 34/50
# 47/47 [==============================] - 86s 2s/step - loss: 0.0670 - categorical_crossentropy: 0.0670 - categorical_accuracy: 0.9155 - mean_iou: 0.4403 - dice_coefficient: 0.8942 - auc: 0.9931 - learning_rate: 3.6668e-04 - val_loss: 0.0790 - val_categorical_crossentropy: 0.0790 - val_categorical_accuracy: 0.9439 - val_mean_iou: 0.4477 - val_dice_coefficient: 0.9032 - val_auc: 0.9958
# Epoch 35/50
# 47/47 [==============================] - 86s 2s/step - loss: 0.0690 - categorical_crossentropy: 0.0690 - categorical_accuracy: 0.9146 - mean_iou: 0.4397 - dice_coefficient: 0.8927 - auc: 0.9931 - learning_rate: 3.4445e-04 - val_loss: 0.0692 - val_categorical_crossentropy: 0.0692 - val_categorical_accuracy: 0.9433 - val_mean_iou: 0.4512 - val_dice_coefficient: 0.9111 - val_auc: 0.9958
# Epoch 36/50
# 47/47 [==============================] - 86s 2s/step - loss: 0.0675 - categorical_crossentropy: 0.0675 - categorical_accuracy: 0.9172 - mean_iou: 0.4405 - dice_coefficient: 0.8941 - auc: 0.9932 - learning_rate: 3.2223e-04 - val_loss: 0.0683 - val_categorical_crossentropy: 0.0683 - val_categorical_accuracy: 0.9428 - val_mean_iou: 0.4516 - val_dice_coefficient: 0.9119 - val_auc: 0.9958
# Epoch 37/50
# 47/47 [==============================] - 86s 2s/step - loss: 0.0670 - categorical_crossentropy: 0.0670 - categorical_accuracy: 0.9188 - mean_iou: 0.4408 - dice_coefficient: 0.8946 - auc: 0.9932 - learning_rate: 3.0001e-04 - val_loss: 0.0678 - val_categorical_crossentropy: 0.0678 - val_categorical_accuracy: 0.9423 - val_mean_iou: 0.4519 - val_dice_coefficient: 0.9124 - val_auc: 0.9957
# Epoch 38/50
# 47/47 [==============================] - 86s 2s/step - loss: 0.0663 - categorical_crossentropy: 0.0663 - categorical_accuracy: 0.9208 - mean_iou: 0.4412 - dice_coefficient: 0.8951 - auc: 0.9933 - learning_rate: 2.7779e-04 - val_loss: 0.0678 - val_categorical_crossentropy: 0.0678 - val_categorical_accuracy: 0.9422 - val_mean_iou: 0.4521 - val_dice_coefficient: 0.9126 - val_auc: 0.9957
# Epoch 39/50
# 47/47 [==============================] - 86s 2s/step - loss: 0.0648 - categorical_crossentropy: 0.0648 - categorical_accuracy: 0.9221 - mean_iou: 0.4418 - dice_coefficient: 0.8964 - auc: 0.9934 - learning_rate: 2.5557e-04 - val_loss: 0.0701 - val_categorical_crossentropy: 0.0701 - val_categorical_accuracy: 0.9430 - val_mean_iou: 0.4514 - val_dice_coefficient: 0.9107 - val_auc: 0.9957
# Epoch 40/50
# 47/47 [==============================] - 86s 2s/step - loss: 0.0651 - categorical_crossentropy: 0.0651 - categorical_accuracy: 0.9239 - mean_iou: 0.4420 - dice_coefficient: 0.8963 - auc: 0.9933 - learning_rate: 2.3334e-04 - val_loss: 0.0681 - val_categorical_crossentropy: 0.0681 - val_categorical_accuracy: 0.9421 - val_mean_iou: 0.4521 - val_dice_coefficient: 0.9123 - val_auc: 0.9957
# Epoch 41/50
# 47/47 [==============================] - 86s 2s/step - loss: 0.0637 - categorical_crossentropy: 0.0637 - categorical_accuracy: 0.9254 - mean_iou: 0.4424 - dice_coefficient: 0.8972 - auc: 0.9937 - learning_rate: 2.1112e-04 - val_loss: 0.0694 - val_categorical_crossentropy: 0.0694 - val_categorical_accuracy: 0.9423 - val_mean_iou: 0.4520 - val_dice_coefficient: 0.9115 - val_auc: 0.9956
# Epoch 42/50
# 47/47 [==============================] - 86s 2s/step - loss: 0.0618 - categorical_crossentropy: 0.0618 - categorical_accuracy: 0.9281 - mean_iou: 0.4433 - dice_coefficient: 0.8988 - auc: 0.9937 - learning_rate: 1.8890e-04 - val_loss: 0.0674 - val_categorical_crossentropy: 0.0674 - val_categorical_accuracy: 0.9438 - val_mean_iou: 0.4528 - val_dice_coefficient: 0.9130 - val_auc: 0.9957
# Epoch 43/50
# 47/47 [==============================] - 86s 2s/step - loss: 0.0601 - categorical_crossentropy: 0.0601 - categorical_accuracy: 0.9301 - mean_iou: 0.4442 - dice_coefficient: 0.9004 - auc: 0.9939 - learning_rate: 1.6668e-04 - val_loss: 0.0678 - val_categorical_crossentropy: 0.0678 - val_categorical_accuracy: 0.9444 - val_mean_iou: 0.4528 - val_dice_coefficient: 0.9128 - val_auc: 0.9958
# Epoch 44/50
# 47/47 [==============================] - 86s 2s/step - loss: 0.0588 - categorical_crossentropy: 0.0588 - categorical_accuracy: 0.9320 - mean_iou: 0.4448 - dice_coefficient: 0.9014 - auc: 0.9940 - learning_rate: 1.4445e-04 - val_loss: 0.0686 - val_categorical_crossentropy: 0.0686 - val_categorical_accuracy: 0.9438 - val_mean_iou: 0.4528 - val_dice_coefficient: 0.9123 - val_auc: 0.9957
# Epoch 45/50
# 47/47 [==============================] - 86s 2s/step - loss: 0.0570 - categorical_crossentropy: 0.0570 - categorical_accuracy: 0.9340 - mean_iou: 0.4456 - dice_coefficient: 0.9029 - auc: 0.9942 - learning_rate: 1.2223e-04 - val_loss: 0.0699 - val_categorical_crossentropy: 0.0699 - val_categorical_accuracy: 0.9431 - val_mean_iou: 0.4526 - val_dice_coefficient: 0.9114 - val_auc: 0.9956
# Epoch 46/50
# 47/47 [==============================] - 86s 2s/step - loss: 0.0555 - categorical_crossentropy: 0.0555 - categorical_accuracy: 0.9358 - mean_iou: 0.4463 - dice_coefficient: 0.9042 - auc: 0.9944 - learning_rate: 1.0001e-04 - val_loss: 0.0717 - val_categorical_crossentropy: 0.0717 - val_categorical_accuracy: 0.9411 - val_mean_iou: 0.4523 - val_dice_coefficient: 0.9103 - val_auc: 0.9954
# Epoch 47/50
# 47/47 [==============================] - 86s 2s/step - loss: 0.0537 - categorical_crossentropy: 0.0537 - categorical_accuracy: 0.9376 - mean_iou: 0.4473 - dice_coefficient: 0.9058 - auc: 0.9946 - learning_rate: 7.7788e-05 - val_loss: 0.0738 - val_categorical_crossentropy: 0.0738 - val_categorical_accuracy: 0.9384 - val_mean_iou: 0.4519 - val_dice_coefficient: 0.9089 - val_auc: 0.9951
# Epoch 48/50
# 47/47 [==============================] - 86s 2s/step - loss: 0.0524 - categorical_crossentropy: 0.0524 - categorical_accuracy: 0.9407 - mean_iou: 0.4485 - dice_coefficient: 0.9073 - auc: 0.9948 - learning_rate: 5.5565e-05 - val_loss: 0.0791 - val_categorical_crossentropy: 0.0791 - val_categorical_accuracy: 0.9306 - val_mean_iou: 0.4512 - val_dice_coefficient: 0.9057 - val_auc: 0.9940
# Epoch 49/50
# 47/47 [==============================] - 86s 2s/step - loss: 0.0533 - categorical_crossentropy: 0.0533 - categorical_accuracy: 0.9446 - mean_iou: 0.4506 - dice_coefficient: 0.9078 - auc: 0.9946 - learning_rate: 3.3343e-05 - val_loss: 0.0750 - val_categorical_crossentropy: 0.0750 - val_categorical_accuracy: 0.9287 - val_mean_iou: 0.4537 - val_dice_coefficient: 0.9095 - val_auc: 0.9937
# Epoch 50/50
# 47/47 [==============================] - 86s 2s/step - loss: 0.0500 - categorical_crossentropy: 0.0500 - categorical_accuracy: 0.9467 - mean_iou: 0.4527 - dice_coefficient: 0.9110 - auc: 0.9947 - learning_rate: 1.1121e-05 - val_loss: 0.0767 - val_categorical_crossentropy: 0.0767 - val_categorical_accuracy: 0.9251 - val_mean_iou: 0.4533 - val_dice_coefficient: 0.9084 - val_auc: 0.9932

# %% [markdown]
# **Task 4**: Let's predict mitochondria in the testing data! [15 Points]

# %%
# 
# After training, let's try the U-Net on our testing data.
#
# The code below displays the first 10 input images, the original masks by experts, 
# and the predicted masks from the U-Net.

# %%
rows = 10
fig, axs = plt.subplots(rows, 3, figsize=(8, 30))
for ax, (image, label) in zip(axs, test.take(rows).batch(1)):
  
  prediction = unet_model.predict(image)
  ax[0].matshow(image[0, :, :, 0])
  ax[1].matshow(label[0, :, :, 1], cmap="gray")
  ax[2].matshow(prediction[0].argmax(axis=-1), cmap="gray")

# %%
# 1) Question
# TODO: Why do we use the prediction[0].argmax(axis=-1) command
# to display the prediction?
# 
# TODO: YOUR ANSWER

# %%
# 2) Question
# TODO: Is the quality of the segmentation good and how could we improve it?
# Hint: Think along the lines of some traditional image processing rather than
# increasing the training data size.
#
# TODO: YOUR ANSWER

# %% [markdown]
# **Bonus**: Compare against the state-of-the-art literature! [33 Points]

# %%
#
# The following paper also uses a 2D U-Net to detect mitochondria:
# 
# https://danielhaehn.com/papers/?casser2020fast
#

# %%
# 1) Question
#
# TODO: How many learnable parameters does your trained unet_model have?
# Hint: You can use TF's Model Summary function to answer this.
#

# %%
# TODO: YOUR CODE

# %%
# 2) Question
#
# TODO: How many parameters do Casser et al. use?
#

# %%
# TODO: YOUR ANSWER

# %%
# 3) Question
#
# TODO: How did Casser et al. reduce the parameters?
#

# %%
# TODO: YOUR ANSWER

# %%
# 4) Question
#
# TODO: Why did Casser et al. reduce the parameters?
#

# %%
# TODO: YOUR ANSWER

# %%
#
# You made it!!
#
#                 _ ___                /^^\ /^\  /^^\_
#     _          _@)@) \            ,,/ '` ~ `'~~ ', `\.
#   _/o\_ _ _ _/~`.`...'~\        ./~~..,'`','',.,' '  ~:
#  / `,'.~,~.~  .   , . , ~|,   ,/ .,' , ,. .. ,,.   `,  ~\_
# ( ' _' _ '_` _  '  .    , `\_/ .' ..' '  `  `   `..  `,   \_
#  ~V~ V~ V~ V~ ~\ `   ' .  '    , ' .,.,''`.,.''`.,.``. ',   \_
#   _/\ /\ /\ /\_/, . ' ,   `_/~\_ .' .,. ,, , _/~\_ `. `. '.,  \_
#  < ~ ~ '~`'~'`, .,  .   `_: ::: \_ '      `_/ ::: \_ `.,' . ',  \_
#   \ ' `_  '`_    _    ',/ _::_::_ \ _    _/ _::_::_ \   `.,'.,`., \-,-,-,_,_,
#    `'~~ `'~~ `'~~ `'~~  \(_)(_)(_)/  `~~' \(_)(_)(_)/ ~'`\_.._,._,'_;_;_;_;_;
#
