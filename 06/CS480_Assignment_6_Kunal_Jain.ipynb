# %% [markdown]
# <a href="https://colab.research.google.com/github/jainkhere/cs480student/blob/main/06/CS480_Assignment_6_Kunal_Jain.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![CS480_w.png](data:image/png;base64,...)
# #Assignment 6

# %%
# In this assignment, we will train a U-Net classifer to detect mitochondria
# in electron microscopy images!

# %%
### IMPORTANT ###
#
# Activate GPU support: Runtime -> Change Runtime Type
# Hardware Accelerator: GPU
#
### IMPORTANT ###

# %%
# load numpy and matplotlib
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# load the unet tensorflow code
# !pip install git+https://github.com/jakeret/unet.git
# Out:
# Collecting git+https://github.com/jakeret/unet.git
#   Cloning https://github.com/jakeret/unet.git to /tmp/pip-req-build-jukfwrbl
#   Running command git clone -q https://github.com/jakeret/unet.git /tmp/pip-req-build-jukfwrbl

# %%
# .. and use it!
# Note: There are a ton of U-Net implementations but this one is easier to use!
import unet

# %% [markdown]
# **Task 1**: Study the unet circle example and learn about mitochondria! [15 Points]

# %%
# The unet package allows to train a U-Net classifier with little code.
# As discussed in class, the U-Net can be used to label/segment/annotate images.

# %%
# TODO: Please study the Circles example 
# https://github.com/jakeret/unet/blob/master/notebooks/circles.ipynb

# %%
# TODO: ... and look how the (artificial) dataset is generated
# https://github.com/jakeret/unet/blob/master/src/unet/datasets/circles.py

# %%
# 1) Question
# TODO: Please describe what the U-Net is trained to do.
#
# TODO: YOUR ANSWER

# U-Net is trained to detect circles in a noisy image

# %%
# 2) Question
# TODO: In circles.py, what does the following mean:
#     channels = 1
#     classes = 2
#
# TODO: YOUR ANSWER

# Channels -> 
# Classes -> 2 classes, one for circle which is foreground and other for background.

# %%
# 3) Question
# TODO: What are mitochondria and what is their appearance in
# electron microscopy data?
# Hint: You can validate your answer in Task 4!
#
# TODO: YOUR ANSWER

# Mitochondria is an organelle the power house of a cell. It appears like rounded or sausage like structure.

# %% [markdown]
# **Task 2**: Setup a datagenerator for mitochondria images! [45 Points]

# %%
# TODO: 
# Download https://cs480.org/data/mito.npz to your computer.
# Then, please upload mito.npz using the file panel on the left.

# %%
# The code below is similar to the circles.py file from Task 1.
# We follow Tensorflow conventions to design a tf.data.Dataset for training
# the U-Net.
#
# TODO: Please add four different data augmentation methods in the code block
# below. (image normalization to 0..1, horizontal data flip, vertical data flip,
# rotation by 90 degrees)
#
# Hint: https://github.com/jakeret/unet/blob/master/src/unet/datasets/oxford_iiit_pet.py#L25

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import tensorflow as tf
import tensorflow_datasets as tfds
from tensorflow_datasets.core import DatasetInfo
from typing import Tuple, List

IMAGE_SIZE = (256, 256)
channels = 1
classes = 2

def load_data(count:int, splits:Tuple[float]=(0.7, 0.2, 0.1), **kwargs) -> List[tf.data.Dataset]:
    return [tf.data.Dataset.from_tensor_slices(_build_samples(int(split * count), **kwargs))
            for split in splits]


def _build_samples(sample_count:int, **kwargs) -> Tuple[np.array, np.array]:

    # here we load the mitochondria data
    loaded = np.load('/content/drive/MyDrive/CS480/mito.npz')
    loadedimages = loaded['arr_0'][0].copy()
    loadedmasks = loaded['arr_0'][1].copy()

    # now let's go to numpyland
    images = np.empty((sample_count, IMAGE_SIZE[0], IMAGE_SIZE[1], 1))
    labels = np.empty((sample_count, IMAGE_SIZE[0], IMAGE_SIZE[1], 2))
    for i in range(sample_count):
        image, mask = loadedimages[i], loadedmasks[i]

        image = image.reshape((IMAGE_SIZE[0], IMAGE_SIZE[1], 1)).astype(np.float)
        mask = mask.reshape((IMAGE_SIZE[0], IMAGE_SIZE[1], 1))

        #
        # TODO: Normalize the image to 0..1
        #
        # TODO: YOUR CODE
        image = tf.cast(image, tf.float32) / 255.0
        mask -= 1

        #
        # TODO: Use Tensorflow to flip the image horizontally
        #
        if tf.random.uniform(()) > 0.5:
            #
            # TODO: YOUR CODE
            #
            image = tf.image.flip_left_right(image)
            mask = tf.image.flip_left_right(mask)

        #
        # TODO: Use Tensorflow to flip the image vertically
        #
        if tf.random.uniform(()) > 0.5:
            #
            # TODO: YOUR CODE
            #
            image = tf.image.flip_up_down(image)
            mask = tf.image.flip_up_down(mask)

        #
        # TODO: Use Tensorflow to rotate the image 90 degrees
        #
        if tf.random.uniform(()) > 0.5:
            #
            # TODO: YOUR CODE
            #
            image = tf.image.rot90(image)
            mask = tf.image.rot90(mask)


        # augmentation done, let's store the image
        images[i] = image

        # here we split the mask to background and foreground
        fg = np.zeros((IMAGE_SIZE[0], IMAGE_SIZE[1], 1), dtype=np.bool)
        fg[mask == 255] = 1
        bg = np.zeros((IMAGE_SIZE[0], IMAGE_SIZE[1], 1), dtype=np.bool)
        bg[mask == 0] = 1
        
        labels[i, :, :, 0] = bg[:,:,0]
        labels[i, :, :, 1] = fg[:,:,0]

    return images, labels

# %% [markdown]
# **Task 3**: Let's train the U-Net! [25 Points]

# %%
#
# We can now create our training, validation, and testing data by calling
# our methods from Task 2.
#
train, val, test = load_data( 660, splits=(0.7, 0.2, 0.1) )
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:73: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:75: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations

# %%
# 1) Question
# TODO: We have in total 660 images + 660 masks. Based on the code above,
# how many images are used for training alone?
#
# TODO: YOUR ANSWER

# 70 percent of total images and mask are used for training. 
# 70 percent of 660 = 462 images and 462 masks

# %%
#
# Let's setup the U-Net!
#
LEARNING_RATE = 1e-3

unet_model = unet.build_model(channels=channels,
                              num_classes=classes,
                              layer_depth=5,
                              filters_root=64,
                              padding="same")

unet.finalize_model(unet_model, learning_rate=LEARNING_RATE)

# %%
#
# And, let's setup the trainer...
#
trainer = unet.Trainer(checkpoint_callback=False,
                       learning_rate_scheduler=unet.SchedulerType.WARMUP_LINEAR_DECAY,
                       warmup_proportion=0.1,
                       learning_rate=LEARNING_RATE)

# %%
#
# ...and train the U-Net for 50 epochs with a batch_size of 10!
#
# TODO: Please complete the code below.
# Hint: Don't forget to use training and validation data.
# Hint 2: This will take roughly 30 minutes!
#
trainer.fit(unet_model,
            #
            # TODO: YOUR CODE
            #
            #
            train,
            val,
            epochs=50,
            batch_size=10
            )
# Out:
# Epoch 1/50
# 47/47 [==============================] - 32s 669ms/step - loss: 0.0370 - categorical_crossentropy: 0.0370 - categorical_accuracy: 0.9564 - mean_iou: 0.4579 - dice_coefficient: 0.9219 - auc_2: 0.9969 - learning_rate: 9.9911e-05 - val_loss: 0.0623 - val_categorical_crossentropy: 0.0623 - val_categorical_accuracy: 0.9429 - val_mean_iou: 0.4586 - val_dice_coefficient: 0.9196 - val_auc_2: 0.9956
# Epoch 2/50
# 47/47 [==============================] - 32s 680ms/step - loss: 0.0455 - categorical_crossentropy: 0.0455 - categorical_accuracy: 0.9452 - mean_iou: 0.4538 - dice_coefficient: 0.9145 - auc_2: 0.9957 - learning_rate: 2.9991e-04 - val_loss: 0.0814 - val_categorical_crossentropy: 0.0814 - val_categorical_accuracy: 0.9210 - val_mean_iou: 0.4517 - val_dice_coefficient: 0.9054 - val_auc_2: 0.9928
# Epoch 3/50
# 47/47 [==============================] - 32s 686ms/step - loss: 0.0509 - categorical_crossentropy: 0.0509 - categorical_accuracy: 0.9425 - mean_iou: 0.4515 - dice_coefficient: 0.9100 - auc_2: 0.9950 - learning_rate: 4.9991e-04 - val_loss: 0.0634 - val_categorical_crossentropy: 0.0634 - val_categorical_accuracy: 0.9488 - val_mean_iou: 0.4568 - val_dice_coefficient: 0.9175 - val_auc_2: 0.9961
# Epoch 4/50
# 47/47 [==============================] - 32s 693ms/step - loss: 0.0445 - categorical_crossentropy: 0.0445 - categorical_accuracy: 0.9451 - mean_iou: 0.4542 - dice_coefficient: 0.9154 - auc_2: 0.9958 - learning_rate: 6.9991e-04 - val_loss: 0.0513 - val_categorical_crossentropy: 0.0513 - val_categorical_accuracy: 0.9578 - val_mean_iou: 0.4619 - val_dice_coefficient: 0.9273 - val_auc_2: 0.9971
# Epoch 5/50
# 47/47 [==============================] - 33s 696ms/step - loss: 0.0360 - categorical_crossentropy: 0.0360 - categorical_accuracy: 0.9567 - mean_iou: 0.4589 - dice_coefficient: 0.9231 - auc_2: 0.9969 - learning_rate: 8.9991e-04 - val_loss: 0.0341 - val_categorical_crossentropy: 0.0341 - val_categorical_accuracy: 0.9665 - val_mean_iou: 0.4681 - val_dice_coefficient: 0.9408 - val_auc_2: 0.9981
# Epoch 6/50
# 47/47 [==============================] - 33s 696ms/step - loss: 0.0355 - categorical_crossentropy: 0.0355 - categorical_accuracy: 0.9574 - mean_iou: 0.4592 - dice_coefficient: 0.9236 - auc_2: 0.9970 - learning_rate: 9.8890e-04 - val_loss: 0.0379 - val_categorical_crossentropy: 0.0379 - val_categorical_accuracy: 0.9638 - val_mean_iou: 0.4673 - val_dice_coefficient: 0.9382 - val_auc_2: 0.9978
# Epoch 7/50
# 47/47 [==============================] - 33s 696ms/step - loss: 0.0321 - categorical_crossentropy: 0.0321 - categorical_accuracy: 0.9615 - mean_iou: 0.4607 - dice_coefficient: 0.9263 - auc_2: 0.9974 - learning_rate: 9.6668e-04 - val_loss: 0.0378 - val_categorical_crossentropy: 0.0378 - val_categorical_accuracy: 0.9629 - val_mean_iou: 0.4674 - val_dice_coefficient: 0.9383 - val_auc_2: 0.9977
# Epoch 8/50
# 47/47 [==============================] - 33s 702ms/step - loss: 0.0310 - categorical_crossentropy: 0.0310 - categorical_accuracy: 0.9624 - mean_iou: 0.4614 - dice_coefficient: 0.9273 - auc_2: 0.9974 - learning_rate: 9.4445e-04 - val_loss: 0.0338 - val_categorical_crossentropy: 0.0338 - val_categorical_accuracy: 0.9650 - val_mean_iou: 0.4686 - val_dice_coefficient: 0.9412 - val_auc_2: 0.9980
# Epoch 9/50
# 47/47 [==============================] - 33s 704ms/step - loss: 0.0306 - categorical_crossentropy: 0.0306 - categorical_accuracy: 0.9632 - mean_iou: 0.4619 - dice_coefficient: 0.9279 - auc_2: 0.9974 - learning_rate: 9.2223e-04 - val_loss: 0.0258 - val_categorical_crossentropy: 0.0258 - val_categorical_accuracy: 0.9688 - val_mean_iou: 0.4716 - val_dice_coefficient: 0.9477 - val_auc_2: 0.9985
# Epoch 10/50
# 47/47 [==============================] - 33s 707ms/step - loss: 0.0285 - categorical_crossentropy: 0.0285 - categorical_accuracy: 0.9653 - mean_iou: 0.4626 - dice_coefficient: 0.9294 - auc_2: 0.9977 - learning_rate: 9.0001e-04 - val_loss: 0.0314 - val_categorical_crossentropy: 0.0314 - val_categorical_accuracy: 0.9657 - val_mean_iou: 0.4701 - val_dice_coefficient: 0.9437 - val_auc_2: 0.9981
# Epoch 11/50
# 47/47 [==============================] - 33s 711ms/step - loss: 0.0268 - categorical_crossentropy: 0.0268 - categorical_accuracy: 0.9670 - mean_iou: 0.4634 - dice_coefficient: 0.9308 - auc_2: 0.9978 - learning_rate: 8.7779e-04 - val_loss: 0.0364 - val_categorical_crossentropy: 0.0364 - val_categorical_accuracy: 0.9590 - val_mean_iou: 0.4685 - val_dice_coefficient: 0.9402 - val_auc_2: 0.9974
# Epoch 12/50
# 47/47 [==============================] - 36s 770ms/step - loss: 0.0265 - categorical_crossentropy: 0.0265 - categorical_accuracy: 0.9675 - mean_iou: 0.4634 - dice_coefficient: 0.9310 - auc_2: 0.9979 - learning_rate: 8.5557e-04 - val_loss: 0.0401 - val_categorical_crossentropy: 0.0401 - val_categorical_accuracy: 0.9583 - val_mean_iou: 0.4674 - val_dice_coefficient: 0.9374 - val_auc_2: 0.9973
# Epoch 13/50
# 47/47 [==============================] - 33s 712ms/step - loss: 0.0265 - categorical_crossentropy: 0.0265 - categorical_accuracy: 0.9678 - mean_iou: 0.4635 - dice_coefficient: 0.9309 - auc_2: 0.9979 - learning_rate: 8.3334e-04 - val_loss: 0.0389 - val_categorical_crossentropy: 0.0389 - val_categorical_accuracy: 0.9603 - val_mean_iou: 0.4679 - val_dice_coefficient: 0.9382 - val_auc_2: 0.9974
# Epoch 14/50
# 47/47 [==============================] - 33s 713ms/step - loss: 0.0257 - categorical_crossentropy: 0.0257 - categorical_accuracy: 0.9687 - mean_iou: 0.4638 - dice_coefficient: 0.9316 - auc_2: 0.9979 - learning_rate: 8.1112e-04 - val_loss: 0.0404 - val_categorical_crossentropy: 0.0404 - val_categorical_accuracy: 0.9591 - val_mean_iou: 0.4674 - val_dice_coefficient: 0.9371 - val_auc_2: 0.9973
# Epoch 15/50
# 47/47 [==============================] - 33s 714ms/step - loss: 0.0253 - categorical_crossentropy: 0.0253 - categorical_accuracy: 0.9694 - mean_iou: 0.4640 - dice_coefficient: 0.9319 - auc_2: 0.9980 - learning_rate: 7.8890e-04 - val_loss: 0.0422 - val_categorical_crossentropy: 0.0422 - val_categorical_accuracy: 0.9596 - val_mean_iou: 0.4667 - val_dice_coefficient: 0.9355 - val_auc_2: 0.9973
# Epoch 16/50
# 47/47 [==============================] - 33s 709ms/step - loss: 0.0252 - categorical_crossentropy: 0.0252 - categorical_accuracy: 0.9697 - mean_iou: 0.4641 - dice_coefficient: 0.9320 - auc_2: 0.9980 - learning_rate: 7.6668e-04 - val_loss: 0.0446 - val_categorical_crossentropy: 0.0446 - val_categorical_accuracy: 0.9594 - val_mean_iou: 0.4659 - val_dice_coefficient: 0.9336 - val_auc_2: 0.9972
# Epoch 17/50
# 47/47 [==============================] - 33s 706ms/step - loss: 0.0254 - categorical_crossentropy: 0.0254 - categorical_accuracy: 0.9690 - mean_iou: 0.4639 - dice_coefficient: 0.9318 - auc_2: 0.9980 - learning_rate: 7.4445e-04 - val_loss: 0.0523 - val_categorical_crossentropy: 0.0523 - val_categorical_accuracy: 0.9516 - val_mean_iou: 0.4631 - val_dice_coefficient: 0.9278 - val_auc_2: 0.9965
# Epoch 18/50
# 47/47 [==============================] - 36s 767ms/step - loss: 0.0259 - categorical_crossentropy: 0.0259 - categorical_accuracy: 0.9688 - mean_iou: 0.4637 - dice_coefficient: 0.9314 - auc_2: 0.9980 - learning_rate: 7.2223e-04 - val_loss: 0.0569 - val_categorical_crossentropy: 0.0569 - val_categorical_accuracy: 0.9514 - val_mean_iou: 0.4613 - val_dice_coefficient: 0.9241 - val_auc_2: 0.9964
# Epoch 19/50
# 47/47 [==============================] - 33s 711ms/step - loss: 0.0259 - categorical_crossentropy: 0.0259 - categorical_accuracy: 0.9679 - mean_iou: 0.4635 - dice_coefficient: 0.9312 - auc_2: 0.9979 - learning_rate: 7.0001e-04 - val_loss: 0.0677 - val_categorical_crossentropy: 0.0677 - val_categorical_accuracy: 0.9371 - val_mean_iou: 0.4575 - val_dice_coefficient: 0.9162 - val_auc_2: 0.9948
# Epoch 20/50
# 47/47 [==============================] - 34s 716ms/step - loss: 0.0257 - categorical_crossentropy: 0.0257 - categorical_accuracy: 0.9686 - mean_iou: 0.4636 - dice_coefficient: 0.9314 - auc_2: 0.9980 - learning_rate: 6.7779e-04 - val_loss: 0.0604 - val_categorical_crossentropy: 0.0604 - val_categorical_accuracy: 0.9514 - val_mean_iou: 0.4599 - val_dice_coefficient: 0.9210 - val_auc_2: 0.9964
# Epoch 21/50
# 47/47 [==============================] - 33s 709ms/step - loss: 0.0268 - categorical_crossentropy: 0.0268 - categorical_accuracy: 0.9659 - mean_iou: 0.4633 - dice_coefficient: 0.9307 - auc_2: 0.9977 - learning_rate: 6.5557e-04 - val_loss: 0.0793 - val_categorical_crossentropy: 0.0793 - val_categorical_accuracy: 0.9226 - val_mean_iou: 0.4532 - val_dice_coefficient: 0.9078 - val_auc_2: 0.9930
# Epoch 22/50
# 47/47 [==============================] - 33s 707ms/step - loss: 0.0240 - categorical_crossentropy: 0.0240 - categorical_accuracy: 0.9699 - mean_iou: 0.4646 - dice_coefficient: 0.9329 - auc_2: 0.9981 - learning_rate: 6.3334e-04 - val_loss: 0.0786 - val_categorical_crossentropy: 0.0786 - val_categorical_accuracy: 0.9241 - val_mean_iou: 0.4538 - val_dice_coefficient: 0.9084 - val_auc_2: 0.9931
# Epoch 23/50
# 47/47 [==============================] - 33s 704ms/step - loss: 0.0264 - categorical_crossentropy: 0.0264 - categorical_accuracy: 0.9686 - mean_iou: 0.4633 - dice_coefficient: 0.9306 - auc_2: 0.9979 - learning_rate: 6.1112e-04 - val_loss: 0.0925 - val_categorical_crossentropy: 0.0925 - val_categorical_accuracy: 0.9157 - val_mean_iou: 0.4483 - val_dice_coefficient: 0.8974 - val_auc_2: 0.9919
# Epoch 24/50
# 47/47 [==============================] - 37s 795ms/step - loss: 0.0266 - categorical_crossentropy: 0.0266 - categorical_accuracy: 0.9670 - mean_iou: 0.4629 - dice_coefficient: 0.9304 - auc_2: 0.9979 - learning_rate: 5.8890e-04 - val_loss: 0.0930 - val_categorical_crossentropy: 0.0930 - val_categorical_accuracy: 0.9147 - val_mean_iou: 0.4482 - val_dice_coefficient: 0.8970 - val_auc_2: 0.9918
# Epoch 25/50
# 47/47 [==============================] - 37s 783ms/step - loss: 0.0261 - categorical_crossentropy: 0.0261 - categorical_accuracy: 0.9674 - mean_iou: 0.4631 - dice_coefficient: 0.9307 - auc_2: 0.9979 - learning_rate: 5.6668e-04 - val_loss: 0.0933 - val_categorical_crossentropy: 0.0933 - val_categorical_accuracy: 0.9106 - val_mean_iou: 0.4482 - val_dice_coefficient: 0.8971 - val_auc_2: 0.9912
# Epoch 26/50
# 47/47 [==============================] - 33s 709ms/step - loss: 0.0271 - categorical_crossentropy: 0.0271 - categorical_accuracy: 0.9670 - mean_iou: 0.4629 - dice_coefficient: 0.9301 - auc_2: 0.9978 - learning_rate: 5.4445e-04 - val_loss: 0.0798 - val_categorical_crossentropy: 0.0798 - val_categorical_accuracy: 0.9317 - val_mean_iou: 0.4530 - val_dice_coefficient: 0.9066 - val_auc_2: 0.9940
# Epoch 27/50
# 47/47 [==============================] - 34s 718ms/step - loss: 0.0244 - categorical_crossentropy: 0.0244 - categorical_accuracy: 0.9691 - mean_iou: 0.4643 - dice_coefficient: 0.9325 - auc_2: 0.9981 - learning_rate: 5.2223e-04 - val_loss: 0.0674 - val_categorical_crossentropy: 0.0674 - val_categorical_accuracy: 0.9400 - val_mean_iou: 0.4578 - val_dice_coefficient: 0.9165 - val_auc_2: 0.9950
# Epoch 28/50
# 47/47 [==============================] - 37s 780ms/step - loss: 0.0230 - categorical_crossentropy: 0.0230 - categorical_accuracy: 0.9715 - mean_iou: 0.4649 - dice_coefficient: 0.9337 - auc_2: 0.9983 - learning_rate: 5.0001e-04 - val_loss: 0.0631 - val_categorical_crossentropy: 0.0631 - val_categorical_accuracy: 0.9440 - val_mean_iou: 0.4595 - val_dice_coefficient: 0.9197 - val_auc_2: 0.9955
# Epoch 29/50
# 47/47 [==============================] - 37s 784ms/step - loss: 0.0223 - categorical_crossentropy: 0.0223 - categorical_accuracy: 0.9723 - mean_iou: 0.4653 - dice_coefficient: 0.9344 - auc_2: 0.9984 - learning_rate: 4.7779e-04 - val_loss: 0.0580 - val_categorical_crossentropy: 0.0580 - val_categorical_accuracy: 0.9470 - val_mean_iou: 0.4615 - val_dice_coefficient: 0.9238 - val_auc_2: 0.9958
# Epoch 30/50
# 47/47 [==============================] - 33s 713ms/step - loss: 0.0220 - categorical_crossentropy: 0.0220 - categorical_accuracy: 0.9727 - mean_iou: 0.4655 - dice_coefficient: 0.9347 - auc_2: 0.9984 - learning_rate: 4.5557e-04 - val_loss: 0.0559 - val_categorical_crossentropy: 0.0559 - val_categorical_accuracy: 0.9482 - val_mean_iou: 0.4623 - val_dice_coefficient: 0.9256 - val_auc_2: 0.9960
# Epoch 31/50
# 47/47 [==============================] - 36s 773ms/step - loss: 0.0212 - categorical_crossentropy: 0.0212 - categorical_accuracy: 0.9736 - mean_iou: 0.4659 - dice_coefficient: 0.9354 - auc_2: 0.9984 - learning_rate: 4.3334e-04 - val_loss: 0.0525 - val_categorical_crossentropy: 0.0525 - val_categorical_accuracy: 0.9517 - val_mean_iou: 0.4636 - val_dice_coefficient: 0.9281 - val_auc_2: 0.9963
# Epoch 32/50
# 47/47 [==============================] - 33s 705ms/step - loss: 0.0207 - categorical_crossentropy: 0.0207 - categorical_accuracy: 0.9744 - mean_iou: 0.4662 - dice_coefficient: 0.9359 - auc_2: 0.9985 - learning_rate: 4.1112e-04 - val_loss: 0.0469 - val_categorical_crossentropy: 0.0469 - val_categorical_accuracy: 0.9570 - val_mean_iou: 0.4657 - val_dice_coefficient: 0.9323 - val_auc_2: 0.9969
# Epoch 33/50
# 47/47 [==============================] - 33s 705ms/step - loss: 0.0200 - categorical_crossentropy: 0.0200 - categorical_accuracy: 0.9751 - mean_iou: 0.4666 - dice_coefficient: 0.9365 - auc_2: 0.9985 - learning_rate: 3.8890e-04 - val_loss: 0.0453 - val_categorical_crossentropy: 0.0453 - val_categorical_accuracy: 0.9586 - val_mean_iou: 0.4663 - val_dice_coefficient: 0.9336 - val_auc_2: 0.9970
# Epoch 34/50
# 47/47 [==============================] - 33s 704ms/step - loss: 0.0194 - categorical_crossentropy: 0.0194 - categorical_accuracy: 0.9760 - mean_iou: 0.4669 - dice_coefficient: 0.9371 - auc_2: 0.9986 - learning_rate: 3.6668e-04 - val_loss: 0.0437 - val_categorical_crossentropy: 0.0437 - val_categorical_accuracy: 0.9603 - val_mean_iou: 0.4668 - val_dice_coefficient: 0.9347 - val_auc_2: 0.9972
# Epoch 35/50
# 47/47 [==============================] - 33s 708ms/step - loss: 0.0192 - categorical_crossentropy: 0.0192 - categorical_accuracy: 0.9760 - mean_iou: 0.4670 - dice_coefficient: 0.9372 - auc_2: 0.9986 - learning_rate: 3.4445e-04 - val_loss: 0.0423 - val_categorical_crossentropy: 0.0423 - val_categorical_accuracy: 0.9612 - val_mean_iou: 0.4674 - val_dice_coefficient: 0.9359 - val_auc_2: 0.9973
# Epoch 36/50
# 47/47 [==============================] - 33s 705ms/step - loss: 0.0186 - categorical_crossentropy: 0.0186 - categorical_accuracy: 0.9767 - mean_iou: 0.4673 - dice_coefficient: 0.9377 - auc_2: 0.9987 - learning_rate: 3.2223e-04 - val_loss: 0.0403 - val_categorical_crossentropy: 0.0403 - val_categorical_accuracy: 0.9627 - val_mean_iou: 0.4681 - val_dice_coefficient: 0.9374 - val_auc_2: 0.9974
# Epoch 37/50
# 47/47 [==============================] - 33s 709ms/step - loss: 0.0186 - categorical_crossentropy: 0.0186 - categorical_accuracy: 0.9769 - mean_iou: 0.4674 - dice_coefficient: 0.9378 - auc_2: 0.9987 - learning_rate: 3.0001e-04 - val_loss: 0.0397 - val_categorical_crossentropy: 0.0397 - val_categorical_accuracy: 0.9634 - val_mean_iou: 0.4684 - val_dice_coefficient: 0.9379 - val_auc_2: 0.9975
# Epoch 38/50
# 47/47 [==============================] - 33s 706ms/step - loss: 0.0183 - categorical_crossentropy: 0.0183 - categorical_accuracy: 0.9771 - mean_iou: 0.4675 - dice_coefficient: 0.9380 - auc_2: 0.9987 - learning_rate: 2.7779e-04 - val_loss: 0.0397 - val_categorical_crossentropy: 0.0397 - val_categorical_accuracy: 0.9631 - val_mean_iou: 0.4684 - val_dice_coefficient: 0.9379 - val_auc_2: 0.9975
# Epoch 39/50
# 47/47 [==============================] - 33s 705ms/step - loss: 0.0182 - categorical_crossentropy: 0.0182 - categorical_accuracy: 0.9773 - mean_iou: 0.4675 - dice_coefficient: 0.9381 - auc_2: 0.9987 - learning_rate: 2.5557e-04 - val_loss: 0.0396 - val_categorical_crossentropy: 0.0396 - val_categorical_accuracy: 0.9632 - val_mean_iou: 0.4684 - val_dice_coefficient: 0.9380 - val_auc_2: 0.9975
# Epoch 40/50
# 47/47 [==============================] - 33s 705ms/step - loss: 0.0180 - categorical_crossentropy: 0.0180 - categorical_accuracy: 0.9776 - mean_iou: 0.4677 - dice_coefficient: 0.9383 - auc_2: 0.9987 - learning_rate: 2.3334e-04 - val_loss: 0.0393 - val_categorical_crossentropy: 0.0393 - val_categorical_accuracy: 0.9633 - val_mean_iou: 0.4685 - val_dice_coefficient: 0.9383 - val_auc_2: 0.9975
# Epoch 41/50
# 47/47 [==============================] - 33s 705ms/step - loss: 0.0178 - categorical_crossentropy: 0.0178 - categorical_accuracy: 0.9777 - mean_iou: 0.4677 - dice_coefficient: 0.9384 - auc_2: 0.9987 - learning_rate: 2.1112e-04 - val_loss: 0.0397 - val_categorical_crossentropy: 0.0397 - val_categorical_accuracy: 0.9627 - val_mean_iou: 0.4683 - val_dice_coefficient: 0.9379 - val_auc_2: 0.9974
# Epoch 42/50
# 47/47 [==============================] - 33s 703ms/step - loss: 0.0177 - categorical_crossentropy: 0.0177 - categorical_accuracy: 0.9780 - mean_iou: 0.4678 - dice_coefficient: 0.9385 - auc_2: 0.9987 - learning_rate: 1.8890e-04 - val_loss: 0.0402 - val_categorical_crossentropy: 0.0402 - val_categorical_accuracy: 0.9619 - val_mean_iou: 0.4682 - val_dice_coefficient: 0.9376 - val_auc_2: 0.9974
# Epoch 43/50
# 47/47 [==============================] - 33s 706ms/step - loss: 0.0177 - categorical_crossentropy: 0.0177 - categorical_accuracy: 0.9779 - mean_iou: 0.4678 - dice_coefficient: 0.9385 - auc_2: 0.9987 - learning_rate: 1.6668e-04 - val_loss: 0.0415 - val_categorical_crossentropy: 0.0415 - val_categorical_accuracy: 0.9606 - val_mean_iou: 0.4677 - val_dice_coefficient: 0.9366 - val_auc_2: 0.9972
# Epoch 44/50
# 47/47 [==============================] - 33s 710ms/step - loss: 0.0173 - categorical_crossentropy: 0.0173 - categorical_accuracy: 0.9783 - mean_iou: 0.4680 - dice_coefficient: 0.9389 - auc_2: 0.9988 - learning_rate: 1.4445e-04 - val_loss: 0.0427 - val_categorical_crossentropy: 0.0427 - val_categorical_accuracy: 0.9594 - val_mean_iou: 0.4673 - val_dice_coefficient: 0.9358 - val_auc_2: 0.9971
# Epoch 45/50
# 47/47 [==============================] - 33s 707ms/step - loss: 0.0172 - categorical_crossentropy: 0.0172 - categorical_accuracy: 0.9785 - mean_iou: 0.4681 - dice_coefficient: 0.9390 - auc_2: 0.9988 - learning_rate: 1.2223e-04 - val_loss: 0.0456 - val_categorical_crossentropy: 0.0456 - val_categorical_accuracy: 0.9566 - val_mean_iou: 0.4662 - val_dice_coefficient: 0.9335 - val_auc_2: 0.9968
# Epoch 46/50
# 47/47 [==============================] - 33s 706ms/step - loss: 0.0166 - categorical_crossentropy: 0.0166 - categorical_accuracy: 0.9790 - mean_iou: 0.4683 - dice_coefficient: 0.9394 - auc_2: 0.9988 - learning_rate: 1.0001e-04 - val_loss: 0.0463 - val_categorical_crossentropy: 0.0463 - val_categorical_accuracy: 0.9562 - val_mean_iou: 0.4660 - val_dice_coefficient: 0.9330 - val_auc_2: 0.9968
# Epoch 47/50
# 47/47 [==============================] - 33s 712ms/step - loss: 0.0163 - categorical_crossentropy: 0.0163 - categorical_accuracy: 0.9791 - mean_iou: 0.4684 - dice_coefficient: 0.9396 - auc_2: 0.9989 - learning_rate: 7.7788e-05 - val_loss: 0.0489 - val_categorical_crossentropy: 0.0489 - val_categorical_accuracy: 0.9536 - val_mean_iou: 0.4650 - val_dice_coefficient: 0.9311 - val_auc_2: 0.9965
# Epoch 48/50
# 47/47 [==============================] - 33s 714ms/step - loss: 0.0160 - categorical_crossentropy: 0.0160 - categorical_accuracy: 0.9795 - mean_iou: 0.4686 - dice_coefficient: 0.9399 - auc_2: 0.9989 - learning_rate: 5.5565e-05 - val_loss: 0.0493 - val_categorical_crossentropy: 0.0493 - val_categorical_accuracy: 0.9531 - val_mean_iou: 0.4649 - val_dice_coefficient: 0.9307 - val_auc_2: 0.9965
# Epoch 49/50
# 47/47 [==============================] - 33s 709ms/step - loss: 0.0158 - categorical_crossentropy: 0.0158 - categorical_accuracy: 0.9797 - mean_iou: 0.4687 - dice_coefficient: 0.9401 - auc_2: 0.9989 - learning_rate: 3.3343e-05 - val_loss: 0.0488 - val_categorical_crossentropy: 0.0488 - val_categorical_accuracy: 0.9536 - val_mean_iou: 0.4651 - val_dice_coefficient: 0.9312 - val_auc_2: 0.9965
# Epoch 50/50
# 47/47 [==============================] - 33s 707ms/step - loss: 0.0157 - categorical_crossentropy: 0.0157 - categorical_accuracy: 0.9798 - mean_iou: 0.4688 - dice_coefficient: 0.9402 - auc_2: 0.9989 - learning_rate: 1.1121e-05 - val_loss: 0.0484 - val_categorical_crossentropy: 0.0484 - val_categorical_accuracy: 0.9539 - val_mean_iou: 0.4652 - val_dice_coefficient: 0.9315 - val_auc_2: 0.9965

# %% [markdown]
# **Task 4**: Let's predict mitochondria in the testing data! [15 Points]

# %%
# 
# After training, let's try the U-Net on our testing data.
#
# The code below displays the first 10 input images, the original masks by experts, 
# and the predicted masks from the U-Net.

# %%
rows = 10
fig, axs = plt.subplots(rows, 3, figsize=(8, 30))
for ax, (image, label) in zip(axs, test.take(rows).batch(1)):
  
  prediction = unet_model.predict(image)
  ax[0].matshow(image[0, :, :, 0])
  ax[1].matshow(label[0, :, :, 1], cmap="gray")
  ax[2].matshow(prediction[0].argmax(axis=-1), cmap="gray")

# %%
# 1) Question
# TODO: Why do we use the prediction[0].argmax(axis=-1) command
# to display the prediction?
# 
# TODO: YOUR ANSWER

# %%
# 2) Question
# TODO: Is the quality of the segmentation good and how could we improve it?
# Hint: Think along the lines of some traditional image processing rather than
# increasing the training data size.
#
# TODO: YOUR ANSWER
# The quality of segmentation is good but not best as there is some noise in segmented data.
# Maybe increasing batch size and epochs can help in improving quality of segmentation.

# %% [markdown]
# **Bonus**: Compare against the state-of-the-art literature! [33 Points]

# %%
#
# The following paper also uses a 2D U-Net to detect mitochondria:
# 
# https://danielhaehn.com/papers/?casser2020fast
#

# %%
# 1) Question
#
# TODO: How many learnable parameters does your trained unet_model have?
# Hint: You can use TF's Model Summary function to answer this.
#

# %%
# TODO: YOUR CODE

# %%
unet_model.summary()
# Out:
# Model: "unet"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  inputs (InputLayer)            [(None, None, None,  0           []
#                                  1)]
#
#  conv_block_18 (ConvBlock)      (None, None, None,   37568       ['inputs[0][0]']
#                                 64)
#
#  max_pooling2d_8 (MaxPooling2D)  (None, None, None,   0          ['conv_block_18[0][0]']
#                                 64)
#
#  conv_block_19 (ConvBlock)      (None, None, None,   221440      ['max_pooling2d_8[0][0]']
#                                 128)
#
#  max_pooling2d_9 (MaxPooling2D)  (None, None, None,   0          ['conv_block_19[0][0]']
#                                 128)
#
#  conv_block_20 (ConvBlock)      (None, None, None,   885248      ['max_pooling2d_9[0][0]']
#                                 256)
#
#  max_pooling2d_10 (MaxPooling2D  (None, None, None,   0          ['conv_block_20[0][0]']
#  )                              256)
#
#  conv_block_21 (ConvBlock)      (None, None, None,   3539968     ['max_pooling2d_10[0][0]']
#                                 512)
#
#  max_pooling2d_11 (MaxPooling2D  (None, None, None,   0          ['conv_block_21[0][0]']
#  )                              512)
#
#  conv_block_22 (ConvBlock)      (None, None, None,   14157824    ['max_pooling2d_11[0][0]']
#                                 1024)
#
#  upconv_block_8 (UpconvBlock)   (None, None, None,   2097664     ['conv_block_22[0][0]']
#                                 512)
#
#  crop_concat_block_8 (CropConca  (None, None, None,   0          ['upconv_block_8[0][0]',
#  tBlock)                        1024)                             'conv_block_21[0][0]']
#
#  conv_block_23 (ConvBlock)      (None, None, None,   7078912     ['crop_concat_block_8[0][0]']
#                                 512)
#
#  upconv_block_9 (UpconvBlock)   (None, None, None,   524544      ['conv_block_23[0][0]']
#                                 256)
#
#  crop_concat_block_9 (CropConca  (None, None, None,   0          ['upconv_block_9[0][0]',
#  tBlock)                        512)                              'conv_block_20[0][0]']
#
#  conv_block_24 (ConvBlock)      (None, None, None,   1769984     ['crop_concat_block_9[0][0]']
#                                 256)
#
#  upconv_block_10 (UpconvBlock)  (None, None, None,   131200      ['conv_block_24[0][0]']
#                                 128)
#
#  crop_concat_block_10 (CropConc  (None, None, None,   0          ['upconv_block_10[0][0]',
#  atBlock)                       256)                              'conv_block_19[0][0]']
#
#  conv_block_25 (ConvBlock)      (None, None, None,   442624      ['crop_concat_block_10[0][0]']
#                                 128)
#
#  upconv_block_11 (UpconvBlock)  (None, None, None,   32832       ['conv_block_25[0][0]']
#                                 64)
#
#  crop_concat_block_11 (CropConc  (None, None, None,   0          ['upconv_block_11[0][0]',
#  atBlock)                       128)                              'conv_block_18[0][0]']
#
#  conv_block_26 (ConvBlock)      (None, None, None,   110720      ['crop_concat_block_11[0][0]']
#                                 64)
#
#  conv2d_56 (Conv2D)             (None, None, None,   130         ['conv_block_26[0][0]']
#                                 2)
#
#  activation_68 (Activation)     (None, None, None,   0           ['conv2d_56[0][0]']
#                                 2)
#
#  outputs (Activation)           (None, None, None,   0           ['activation_68[0][0]']
#                                 2)
#
# ==================================================================================================
# Total params: 31,030,658
# Trainable params: 31,030,658
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Total parameters - 31,030,658
# Total trainable parameters - 31,030,658

# %%
# 2) Question
#
# TODO: How many parameters do Casser et al. use?
#
# Number of parameters used for encoders - 1,178,480
# Number of parameters used for decoders - 780,053

# %%
# 3) Question
#
# TODO: How did Casser et al. reduce the parameters?
#

# %%
# TODO: YOUR ANSWER

# They reduced the number of convolutional filters throughout the network. They then replaced
# transpose convolutions in the decoder with light-weight bilinear upsampling layers that
# required no parameters. Lastly, they replaced center-cropping from the original U-Net with padding to output
# densely at full resolution. This modification increased the throughput by an additional 40%.

# %%
# 4) Question
#
# TODO: Why did Casser et al. reduce the parameters?
#

# %%
# TODO: YOUR ANSWER

# To make the segmentation process and to achieve segementation of Mitochondria in real time, 
# faster than currently available segmentation processes

# %%
#
# You made it!!
#
#                 _ ___                /^^\ /^\  /^^\_
#     _          _@)@) \            ,,/ '` ~ `'~~ ', `\.
#   _/o\_ _ _ _/~`.`...'~\        ./~~..,'`','',.,' '  ~:
#  / `,'.~,~.~  .   , . , ~|,   ,/ .,' , ,. .. ,,.   `,  ~\_
# ( ' _' _ '_` _  '  .    , `\_/ .' ..' '  `  `   `..  `,   \_
#  ~V~ V~ V~ V~ ~\ `   ' .  '    , ' .,.,''`.,.''`.,.``. ',   \_
#   _/\ /\ /\ /\_/, . ' ,   `_/~\_ .' .,. ,, , _/~\_ `. `. '.,  \_
#  < ~ ~ '~`'~'`, .,  .   `_: ::: \_ '      `_/ ::: \_ `.,' . ',  \_
#   \ ' `_  '`_    _    ',/ _::_::_ \ _    _/ _::_::_ \   `.,'.,`., \-,-,-,_,_,
#    `'~~ `'~~ `'~~ `'~~  \(_)(_)(_)/  `~~' \(_)(_)(_)/ ~'`\_.._,._,'_;_;_;_;_;
#
